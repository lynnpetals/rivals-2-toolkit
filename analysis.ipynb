# %%
import os
import json
import math

# Edit these paths if needed.
dest = 'r2data_patch_1000.json' # REPLACE THIS WITH THE PATH TO YOUR PATCH

# %%
# RUN THIS CELL TO LOAD YOUR PATCH.
json_path = dest

char_data = json.load(open(json_path, 'r'))

def get_stats(character):
    return char_data[character]['Stats']
def print_stats(character):
    strung = '{{Character-ROA2\n'
    strung += '| chara = ' + character + '\n'

    for k, v in char_data[character]['Stats'].items():
        if k == 'WallJumpSpeed':
            strung += '| WallJumpSpeedX = ' + str(v['X']) + '\n'
        else:
            strung += '| ' + k + ' = ' + str(v) + '\n'
    strung += '}}'
    return strung
def print_move(character, move, images, timings):
    base_string = ''
    for k, v in char_data[character][move]['KBs'].items():
        strung = '{{FrameData-ROA2 | character = ' + character + '\n'
        if move in move_name_conversion.keys():
            strung += '| attack             = ' + move_name_conversion[move] + '\n'
        else:
            strung += '| attack             = ' + move + '\n'

        if(images):
            strung += '| images        = ' + images['image'] + '\n'
            strung += '| hitboxes      = ' + images['hitboxes'] + '\n'
            strung += '| caption       = ' + images['caption'] + '\n'
            strung += '| hitboxCaption = ' + images['hitboxCaption'] + '\n'
        strung += '| name               = ' + k + '\n'
        # if(timings):
        strung += '| startup       = \n'
        strung += '| active        = \n'
        strung += '| iasa          = \n'
        strung += '| endlag        = \n'
        if(move in ['Nair', 'Bair', 'Dair', 'Fair', 'Uair']):
            strung += '| landlag       = ' + str(char_data[character][move]['Windows']['Landing Lag']) + '\n'
        else:
            strung += '| landlag       = N/A\n'
        strung += '| damage             = ' + str(v['damage']) + '%\n'
        strung += '| baseKb             = ' + str(v['base_kb']) + '\n'
        strung += '| kbScale            = ' + str(v['kb_scale']) + '\n'
        strung += '| angle              = ' + str(v['angle']) + '\n'
        strung += '| autoFloorhugFlag   = ' + str(v['auto_floorhug']) + '\n'

        strung += '| isProjectileFlag   = ' + str(char_data[character][move]['ExtraProps']['isProjectileFlag']) + '\n'
        strung += '| isArticleFlag      = ' + str(char_data[character][move]['ExtraProps']['isArticleFlag']) + '\n'
        strung += '| bReverseCat        = ' + str(char_data[character][move]['ExtraProps']['bReverseCat']) + '\n'

        strung += '| hitpauseMulti                  = ' + str(v['hitpause_multi']) + '\n'
        strung += '| extraOppHitpause               = ' + str(v['extra_hitpause']) + '\n'
        total_hp = min(math.floor(((0.4 * (v['base_kb'] + v['kb_scale'] * 17.5) + 3) * v['hitpause_multi'])) + v['extra_hitpause'], 24)
        strung += '| totalHitpause                  = ' + str(total_hp) + '\n'
        strung += '| hitpauseMovementStrength       = ' + str(v['hitpause_multi']) + '\n'

        strung += '| ssdiMulti                      = ' + str(v['sdi_multi']) + '\n'
        if(v['asdi_multi'] == -1.0):
            strung += '| asdiMulti                      = ' + str(v['sdi_multi']) + '\n'
        else:
            strung += '| asdiMulti                      = ' + str(v['asdi_multi']) + '\n'
        strung += '| reverseHitFlag                 = ' + str(v['reverse_flag']) + '\n'
        strung += '| forceFlinchFlag                = ' + str(v['force_flinch']) + '\n'
        strung += '| groundTechableFlag             = ' + str(v['ground_techable']) + '\n'
        strung += '| breakProjectileFlag            = ' + str(v['breaks_projectiles']) + '\n'
        strung += '| weightIndependentFlag          = ' + str(v['weight_independent']) + '\n'
        strung += '| knockbackFlipper               = ' + str(v['kb_flipper']) + '\n'
        strung += '| hitstunMulti                   = ' + str(v['hitstun']) + '\n'
        strung += '| hitfall_stun_multi             = ' + str(v['hitfall_stun']) + '\n'
        strung += '| parryReaction                  = ' + str(v['parry_stun']) + '\n'
        strung += '| grabPartnerInteraction         = ' + str(v['grab_partner']) + '\n'

        strung += '| extraShieldStun                = ' + str(v['extra_shield_stun']) + '\n'
        strung += '| totalShieldStun                = ' + str(v['shield_stun']) + '\n'

        strung += '| shieldDamageMulti              = ' + str(v['shield_damage']) + '\n'
        strung += '| totalShieldDamage              = ' + str("{:.2f}\n".format((v['shield_damage'] * (0.0443*v['damage']*v['damage']+0.6831*v['damage']+0.1244))))

        strung += '| shieldPushbackMulti            = ' + str(v['shield_push']) + '\n'
        strung += '| totalShieldPushback            = ' + str('') + '\n'

        strung += '| shieldHitpauseMulti            = ' + str(v['shield_hitpause']) + '\n'
        if(char_data[character][move]['ExtraProps']['isProjectileFlag']):
            strung += '| totalShieldHitpause            = ' + str(math.floor(total_hp / 2 * v['shield_hitpause'])) + '\n'
        else:
            strung += '| totalShieldHitpause            = ' + str(math.floor(total_hp * v['shield_hitpause'])) + '\n'

        strung += '| fullChargeKbMulti              = ' + str(v['fully_charged_kb_multi']) + '\n'
        strung += '| fullChargeDamageMulti          = ' + str(v['fully_charged_dmg_multi']) + '\n'
        strung += '| finalBaseKb                    = ' + str(v['final_base_kb']) + '\n'
        strung += '| forceTumbleFlag                = ' + str(v['force_tumble']) + '\n'
        # strung += '| ignoreKnockbackArmor                = ' + str(v['fully_charged_kb_multi']) + '\n'
        strung += '}}\n'
        base_string += strung
    for v in char_data[character][move]['Throws']:
        strung = '{{FrameData-ROA2 | character = ' + character + '\n'
        strung += '| attack             = ' + move + '\n'
        strung += '| name               = ' + move + ' [Throw]' + '\n'
        strung += '| startup       = \n'
        strung += '| active        = \n'
        strung += '| iasa          = \n'
        strung += '| endlag        = \n'
        strung += '| isThrowFlag = True\n'
        strung += '| landlag             = N/A\n'
        strung += '| damage             = ' + str(v['damage']) + '%\n'
        strung += '| angle              = ' + str(v['angle']) + '\n'
        strung += '| baseKb                 = ' + str(v['base_kb']) + '\n'
        strung += '| kbScale                 = ' + str(v['kb_scale']) + '\n'
        strung += '| groundTechableFlag       = ' + str(v['ground_techable']) + '\n'
        strung += '| weightIndependentFlag       = True' + '\n'
        strung += '| hitstunMulti       = ' + str(v['hitstun']) + '\n'
        strung += '| totalShieldStun             = N/A\n'        
        strung += '}}\n'
        base_string += strung
    return base_string
def print_all_knockbacks(char_name):
    str1 = ''
    for i in char_data[char_name].keys():
        if(i != 'Stats'):
            str1 += print_move(char_name, i)
    print(str1)

move_name_conversion = {'Bair': 'Back Air',
 'Bthrow': 'Back Throw',
 'Dair': 'Down Air',
 'DspecialAir': 'Down Special (Aerial)',
 'UspecialAir': 'Up Special (Aerial)',
 'DashGrab': 'Dash Grab',
 'Dattack': 'Dash Attack',
 'Dspecial': 'Down Special',
 'Dspecial_Clone': 'Down Special (Clone)',
 'Fspecial_Clone': 'Side Special (Clone)',
 'Dstrong': 'Down Strong',
 'Dthrow': 'Down Throw',
 'Dtilt': 'Down Tilt',
 'Fair': 'Forward Air',
 'Fspecial': 'Side Special',
 'Fstrong': 'Forward Strong',
 'Fthrow': 'Forward Throw',
 'Ftilt': 'Forward Tilt',
 'GetupAttack': 'Getup Attack',
 'GetupSpecial': 'Getup Special',
 'Grab': 'Grab',
 'Jab': 'Jab',
 'LedgeAttack': 'Ledge Attack',
 'LedgeSpecial': 'Ledge Special',
 'Nair': 'Neutral Air',
 'Nspecial': 'Neutral Special',
 'PivotGrab': 'Pivot Grab',
 'Pummel': 'Pummel',
 'PummelSpecial': 'Special Pummel',
 'Uair': 'Up Air',
 'Uspecial': 'Up Special',
 'Ustrong': 'Up Strong',
 'Uthrow': 'Up Throw',
 'Utilt': 'Up Tilt'}

# %% [markdown]
# Character Stats:

# %%
# Ignore this cell in most cases. This cell generates the Dragdown template for character stats.
print(print_stats('Etalus'))
# Out:
# {{Character-ROA2
# | chara = Etalus
# | DacusSpeedMultiplier = 1
# | Weight = 106
# | FrictionGround = 0.43
# | FrictionAir = 0.13
# | DashFrames = 14
# | DashSpeed = 14.2
# | DashAcceleration = 3.68
# | RunSpeedMax = 14.2
# | RunTurnAcceleration = 0.7
# | RunTurnFrames = 28
# | WalkAccelerationMax = 0.56
# | WalkSpeedMax = 9.5
# | Gravity = 1.56
# | HitstunGravity = 1.5
# | FallSpeedMax = 27.6
# | FastFallSpeed = 37.0
# | AirAcceleration = 0.85
# | AirSpeedHorizontalMax = 11.33
# | JumpSpeedHorizontalMax = 17.0
# | FullHopSpeed = 32.0
# | ShortHopSpeed = 22.5
# | DoubleJumpSpeed = 31.0
# | DoubleJumpMaxHorizontalSpeed = 12.0
# | AirDodgeSpeed = 21.25
# | AirDodgeFriction = 1.1
# | RollSpeed = 28.0
# | ShieldSizeMultiplier = 1.4
# | LedgeStandSpeed = 10.0
# | LedgeRollSpeed = 26.0
# | LedgeJumpMaxHorizontalAirSpeed = 11.0
# | GetupRollSpeed = 27.0
# | TechRollSpeed = 29.0
# | WallJumpSpeedX = 19.8
# | WallJumpSpeedY = 25.66
# }}

# %% [markdown]
# Frame Data:

# %%
# RUN THIS CELL TO GET CHARACTER DATA
# This should primarily be for viewing frame data and determining the timing on frames.

forest_list = ['Jab', 'Ftilt', 'Utilt', 'Dtilt', 'Dattack', 'Fstrong', 'Ustrong', 'Dstrong', 'Nair', 'Fair', 'Bair', 'Dair', 'Uair', 'Nspecial', 'Fspecial', 'Uspecial', 'Dspecial', 'Grab', 'DashGrab', 'PivotGrab', 'Pummel', 'PummelSpecial', 'Fthrow', 'Bthrow', 'Uthrow', 'Dthrow', 'LedgeAttack', 'LedgeSpecial', 'GetupAttack', 'GetupSpecial']

def add_data(i):
    str1 = ''
    str2 = ''
    # str1 += print_move(chare, i, {}, {}) # Toggle commenting this line to display the hit data. This line is not necessary for existing characters.
    str1 += '====' + i + '====\n'
    loaded = dict()
    for k, v in char_data[chare][i]['Windows'].items():
        if(k not in loaded.keys()):
            loaded[k] = 1
        if(k == 'Landing Lag'):
            continue
        if(k == 'Charging' or k == 'Charge'):
            loaded[v['Next Window']] = loaded[k]
            continue
        str1 += k + ': ' + (str(loaded[k]) + '-' + str(loaded[k] + v['Length'] - 1)) + ' [' + str(v['Length']) + '] -> ' + str(v['Next Window']) + '\n'
        loaded[v['Next Window']] = loaded[k] + v['Length']
        if('Cancels' in v.keys()):
            for w in v['Cancels']:
                str1 += '\t[CANCEL: ' + w['cancel_type'] + '> ' 
                
                
                lens = w['start'] + w['length'] - 2
                if(lens > 1000):
                    str1 += '\n\t\tIASA: ' + str(loaded[k] + w['start'] - 1) + '+'
                    str1 += '\n\t\tENDLAG: ' + str(w['start'] - 1) + '+'
                else:
                    str1 += '\n\t\tIASA: ' + str(loaded[k] + w['start'] - 1) + '-' + str(loaded[k] + lens)
                    str1 += '\n\t\tENDLAG: ' + str(w['start'] - 1) + '-' + str(lens)
                str1 += '\n'
                    # str1 += '\n\t\tLENGTH:' + str(lens) + ']\n'
        if('Hitboxes' in v.keys()):
            loaded_hitboxes = dict()
            invert = dict()
            for k2, v2 in char_data[chare][i]['Hitboxes'].items():
                for hit in v2:
                    invert[hit] = k2
            # print(i)
            for k3, v3 in v['Hitboxes'].items():
                # print(k3, v3)
                if(k3 not in invert.keys()):
                    continue
                elif(invert[k3] not in loaded_hitboxes.keys()):
                    loaded_hitboxes[invert[k3]] = list()
                    end = v3['End'] + 1
                    if(v3['End'] == 0  or v3['End'] < v3['Start']):
                        end = v['Length'] + 1
                    for a in range(v3['Start'], end):
                        loaded_hitboxes[invert[k3]].append(a)
                else:
                    end = v3['End'] + 1
                    if(v3['End'] == 0 or v3['End'] < v3['Start']):
                        end = v['Length'] + 1
                    for a in range(v3['Start'], end):
                        if(a not in loaded_hitboxes[invert[k3]]):
                            loaded_hitboxes[invert[k3]].append(a)
            new_gen = dict()
            for k5, v5 in loaded_hitboxes.items():
                # print(loaded_hitboxes)
                h = sorted(v5)
                # print(i+k5 + str(h))
                new_gen[k5] = str(loaded[k] + h[0] - 1)
                start_2 = h[0]
                start_3 = h[0]
                for a in h:
                    if a - start_3 <= 1:
                        start_3 = a
                        # print(a)
                    else:
                        if start_2 != start_3:
                            new_gen[k5] += '-' + str(loaded[k] + start_3 - 1) + ', ' + str(loaded[k] + a - 1)
                            start_2 = a
                        else:
                            new_gen[k5] += ', ' + str(loaded[k] + a - 1)
                            start_2 = a
                if start_2 != start_3:
                    new_gen[k5] += '-' + str(loaded[k] + start_3 - 1)
                str1 += '\t' + k5 + ': ' + new_gen[k5] + '\n'
            # print(new_gen)
            # print(v['Hitboxes'])
    return str1
for x in char_data.keys():
    chare = x
    print('\n= {} =\n'.format(chare))
    for i in forest_list:
        print(add_data(i))

    for i in char_data[chare].keys():
        # print(i)
        if(i == 'Stats' or i in forest_list):
            continue
        if 'KBs' in char_data[chare][i].keys():
            print(add_data(i))
            # for k,v in char_data[chare][i]['KBs'].items():
            #     print(i + ' / ' + k + ' / ' + str(v['shield_damage'] * (0.0443*v['damage']*v['damage']+0.6831*v['damage']+0.1244)))
# Out:
# = Clairen =
#
# ====Jab====
# Startup: 1-5 [5] -> Active
# Active: 6-7 [2] -> Recovery
# 	Sour: 6-7
# 	Tipper: 6-7
# Recovery: 8-27 [20] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 23+
# 		ENDLAG: 15+
#
# ====Ftilt====
# Startup: 1-7 [7] -> Active
# Active: 8-11 [4] -> Recovery
# 	Sour: 8-11
# 	Tipper: 8-11
# Recovery: 12-34 [23] ->
#
# ====Utilt====
# Startup: 1-8 [8] -> Active
# Active: 9-15 [7] -> Recovery
# 	Sour: 9-15
# 	Tipper: 9-15
# Recovery: 16-34 [19] ->
#
# ====Dtilt====
# Startup: 1-6 [6] -> Active
# Active: 7-9 [3] -> Recovery
# 	Sour: 7-9
# 	Tipper: 7-9
# Recovery: 10-24 [15] ->
#
# ====Dattack====
# Startup: 1-14 [14] -> Active
# Active: 15-18 [4] -> Recovery
# 	Sour: 15-18
# 	Tipper: 16-18
# Recovery: 19-42 [24] ->
#
# ====Fstrong====
# Pre-Charge: 1-8 [8] -> Charge
# Post-Charge: 9-10 [2] -> Active
# Active: 11-14 [4] -> Recovery
# 	Sour: 11-14
# 	Tipper: 11-14
# Recovery: 15-52 [38] ->
#
# ====Ustrong====
# Pre-Charge: 1-9 [9] -> Charge
# Post-Charge: 10-11 [2] -> Active
# Active: 12-14 [3] -> Recovery
# 	Sour: 12-14
# 	Super Sour: 12-14
# 	Tipper: 12-14
# Recovery: 15-47 [33] ->
#
# ====Dstrong====
# Pre-Charge: 1-3 [3] -> Charge
# Post-Charge: 4-7 [4] -> Active 1
# Active 1: 8-10 [3] -> Between Hits
# 	Sour 1: 8-10
# 	Tipper 1: 8-10
# Between Hits: 11-19 [9] -> Active 2
# Active 2: 20-22 [3] -> Recovery
# 	Sour 2: 20-22
# 	Tipper 2: 20-22
# Recovery: 23-49 [27] ->
#
# ====Nair====
# Startup: 1-9 [9] -> Active 1
# Active 1: 10-10 [1] -> Between 1
# 	Multihit Sour: 10
# 	Multihit Tipper: 10
# Between 1: 11-11 [1] -> Active 2
# Active 2: 12-12 [1] -> Between 2
# 	Multihit Sour: 12
# 	Multihit Tipper: 12
# Between 2: 13-13 [1] -> Active 3
# Active 3: 14-14 [1] -> Between 3
# 	Multihit Sour: 14
# 	Multihit Tipper: 14
# Between 3: 15-15 [1] -> Active 4
# Active 4: 16-16 [1] -> Between 4
# 	Multihit Sour: 16
# 	Multihit Tipper: 16
# Between 4: 17-17 [1] -> Active 5
# Active 5: 18-18 [1] -> Between 5
# 	Multihit Sour: 18
# 	Multihit Tipper: 18
# Between 5: 19-19 [1] -> Active 6
# Active 6: 20-23 [4] -> Recovery
# 	Final Sour: 20-23
# 	Final Tipper: 20-23
# Recovery: 24-35 [12] ->
#
# ====Fair====
# Startup: 1-6 [6] -> Active 1
# Active 1: 7-8 [2] -> Between Hits
# 	Sour 1: 7-8
# 	Reverse Tipper: 8
# 	Tipper: 7-8
# Between Hits: 9-15 [7] -> Active 2
# Active 2: 16-17 [2] -> Recovery
# 	Sour 2: 16-17
# 	Super Sour 2: 16-17
# 	Reverse Tipper: 17
# 	Tipper: 16-17
# Recovery: 18-39 [22] ->
#
# ====Bair====
# Startup: 1-8 [8] -> Active
# Active: 9-11 [3] -> Recovery
# 	Sour: 9-11
# 	Sour Reverse: 9-11
# 	Tipper: 9-11
# Recovery: 12-34 [23] ->
#
# ====Dair====
# Startup: 1-15 [15] -> Active
# Active: 16-21 [6] -> Recovery
# 	Tipper Early: 16-18
# 	Sour Early: 16-18
# 	Sour Late: 19-21
# 	Tipper Late: 19-21
# Recovery: 22-48 [27] ->
#
# ====Uair====
# Startup: 1-15 [15] -> Active
# Active: 16-19 [4] -> Recovery
# 	Sour: 16-19
# 	Tipper: 16-19
# Recovery: 20-45 [26] ->
#
# ====Nspecial====
# Startup: 1-6 [6] -> Charging Loop
# Charging Loop: 7-36 [30] -> Charging Loop
# Strafe Forward: 1-60 [60] -> Strafe Forward
# Strafe Stop Forward: 1-8 [8] -> Charging Loop
# Strafe Backward: 1-60 [60] -> Strafe Backward
# Strafe Stop Backward: 1-8 [8] -> Charging Loop
# Release: 1-4 [4] -> Active
# Active: 5-6 [2] -> Recovery
# Recovery: 7-32 [26] ->
# 	[CANCEL: StateInt1>
# 		IASA: 7-7
# 		ENDLAG: 0-0
# Charged Recovery: 1-38 [38] ->
# Release Upward: 1-4 [4] -> Active Upward
# Active Upward: 5-6 [2] -> Recovery Upward
# Recovery Upward: 7-32 [26] ->
# 	[CANCEL: StateInt1>
# 		IASA: 7-7
# 		ENDLAG: 0-0
# Charged Recovery Upward: 1-38 [38] ->
# Release Downward: 1-4 [4] -> Active Downward
# Active Downward: 5-6 [2] -> Recovery Downward
# Recovery Downward: 7-32 [26] ->
# 	[CANCEL: StateInt1>
# 		IASA: 7-7
# 		ENDLAG: 0-0
# Charged Recovery Downward: 1-38 [38] ->
# Fully Charged Release: 1-30 [30] -> Fully Charged Active
# Fully Charged Active: 31-32 [2] -> Fully Charged Whiff Recovery
# 	[CANCEL: OnPlayerHit>
# 		IASA: 33+
# 		ENDLAG: 2+
# Fully Charged Whiff Recovery: 33-122 [90] ->
# Fully Charged Hit Recovery: 1-90 [90] ->
#
# ====Fspecial====
# Startup: 1-16 [16] -> Movement
# Movement: 17-22 [6] -> Post-Movement Startup
# Post-Movement Startup: 23-25 [3] -> Active
# Active: 26-28 [3] -> Stalled Recovery
# 	[CANCEL: OnObjectHit>
# 		IASA: 29+
# 		ENDLAG: 3+
# Stalled Recovery: 29-39 [11] -> Grounded Recovery
# 	[CANCEL: Aerial>
# 		IASA: 40+
# 		ENDLAG: 11+
# Grounded Recovery: 40-64 [25] ->
# 	[CANCEL: Aerial>
# 		IASA: 39+
# 		ENDLAG: -1+
# Aerial Recovery: 1-12 [12] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 1-5
# 		ENDLAG: 0-4
# 	[CANCEL: Grounded>
# 		IASA: 6+
# 		ENDLAG: 5+
# Special Fall: 13-28 [16] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 28+
# 		ENDLAG: -1+
# Special Land: 1-15 [15] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# On-Hit Recovery: 1-11 [11] ->
#
# ====Uspecial====
# Startup: 1-15 [15] -> Active 1
# Active 1: 16-17 [2] -> Active 2
# 	Multihit Early: 16-17
# Active 2: 18-19 [2] -> Active 3
# 	Multihit Early: 18-19
# Active 3: 20-21 [2] -> Active 4
# 	Multihit Early: 20-21
# Active 4: 22-23 [2] -> Active 5
# 	Multihit Early: 22-23
# Active 5: 24-25 [2] -> Transition Start
# 	Multihit Late: 24-25
# Transition Start: 26-27 [2] -> Transition Window
# Transition Window: 28-33 [6] -> Recovery
# 	[CANCEL: SpecialDown>
# 		IASA: 34-34
# 		ENDLAG: 6-6
# 	[CANCEL: StateInt0>
# 		IASA: 34-34
# 		ENDLAG: 6-6
# Recovery: 34-51 [18] -> Looping Special Fall 1
# 	[CANCEL: Grounded>
# 		IASA: 33+
# 		ENDLAG: -1+
# Looping Special Fall 1: 52-65 [14] -> Looping Special Fall 1
# 	[CANCEL: Grounded>
# 		IASA: 65+
# 		ENDLAG: -1+
# Special Land 1: 1-24 [24] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# Finisher Startup: 1-10 [10] -> Finisher Active
# Finisher Active: 11-15 [5] -> Finisher Recovery
# 	Final Sour: 11-15
# 	Final Tipper: 11-15
# Finisher Recovery: 16-40 [25] -> Looping Special Fall 2
# 	[CANCEL: Grounded>
# 		IASA: 15+
# 		ENDLAG: -1+
# Looping Special Fall 2: 41-54 [14] -> Looping Special Fall 2
# 	[CANCEL: Grounded>
# 		IASA: 54+
# 		ENDLAG: -1+
# Special Land 2: 1-30 [30] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
#
# ====Dspecial====
# Startup: 1-6 [6] -> Active
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 7+
# 		ENDLAG: 6+
# Active: 7-23 [17] -> Recovery
# 	[CANCEL: OnCounter>
# 		IASA: 6+
# 		ENDLAG: -1+
# Recovery: 24-54 [31] ->
# Attack Startup: 1-4 [4] -> Active 1
# Active 1: 5-8 [4] -> Active 2
# 	Projectile Killer KB: 5-8
# 	Multihits: 5-8
# Active 2: 9-12 [4] -> Active 3
# 	Projectile Killer KB: 9-12
# 	Multihits: 9-12
# Active 3: 13-16 [4] -> Attack Recovery
# 	Projectile Killer KB: 13-16
# 	Final Hit: 13-16
# Attack Recovery: 17-22 [6] ->
# Cooldown: 1-8 [8] ->
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====Fthrow====
# Startup: 1-9 [9] -> Active
# Active: 10-10 [1] -> Recovery
# 	Tipper: 10
# 	Sour: 10
# Recovery: 11-26 [16] ->
#
# ====Bthrow====
# Startup: 1-13 [13] -> Active
# Active: 14-14 [1] -> Recovery
# 	Tipper: 14
# 	Sour: 14
# Recovery: 15-33 [19] ->
#
# ====Uthrow====
# Startup: 1-16 [16] -> Active
# Active: 17-19 [3] -> Recovery
# 	Tipper: 17-19
# 	Sour: 17-19
# Recovery: 20-49 [30] ->
#
# ====Dthrow====
# Startup: 1-16 [16] -> Active
# Active: 17-18 [2] -> Recovery
# 	Tipper: 17-18
# 	Sour: 17-18
# Recovery: 19-43 [25] ->
#
# ====LedgeAttack====
# Startup: 1-23 [23] -> Active
# Active: 24-30 [7] -> Recovery
# 	Sour: 24-30
# 	Tipper: 24-30
# Recovery: 31-55 [25] ->
#
# ====LedgeSpecial====
# Startup: 1-20 [20] -> Jumping Startup
# Jumping Startup: 21-32 [12] -> Active
# Active: 33-37 [5] -> Recovery
# 	Sour Ground: 33-37
# 	Sour Air: 33-37
# Recovery: 38-69 [32] ->
# 	[CANCEL: Grounded>
# 		IASA: 37+
# 		ENDLAG: -1+
# Landing: 1-30 [30] ->
#
# ====GetupAttack====
# Startup: 1-16 [16] -> Active 1
# Active 1: 17-19 [3] -> Between Hits
# 	Sour: 17-19
# 	Tipper: 17-19
# Between Hits: 20-24 [5] -> Active 2
# Active 2: 25-27 [3] -> Recovery
# 	Sour: 25-27
# 	Tipper: 25-27
# Recovery: 28-50 [23] ->
#
# ====GetupSpecial====
# Startup: 1-20 [20] -> Reappearing
# Reappearing: 21-24 [4] -> Active
# Active: 25-28 [4] -> Recovery
# 	Sour: 25-29
# 	Tipper: 25-29
# Recovery: 29-68 [40] ->
#
# ====Intro====
# Full Intro: 1-120 [120] ->
#
# ====Taunt_Default====
# Full Taunt: 1-110 [110] ->
#
# ====Taunt_Oath====
# Full Taunt: 1-100 [100] ->
#
# ====FspecialX====
# Startup: 1-10 [10] -> Active
# Active: 11-13 [3] -> Recovery
# 	Tipper: 11-13
# 	Sour: 11-13
# Recovery: 14-39 [26] ->
#
# ====GroundPlasma====
# Startup: 1-20 [20] -> Active
# Active: 21-23 [3] ->
# 	Lspecial: 21-23
#
# ====PlasmaField====
# Startup: 1-4 [4] -> Active 1
# Active 1: 5-8 [4] -> Active 2
# Active 2: 9-12 [4] -> Active 3
# Active 3: 13-16 [4] -> Idle
# Idle: 17-616 [600] -> Despawn
# 	Proj KB: 17-616
# Despawn: 617-646 [30] ->
#
# ====QuickSlash====
# Startup 1: 1-4 [4] -> Active 1
# Active 1: 5-6 [2] -> Recovery 1
# 	Sour 1: 5-6
# 	Tipper 1: 5-6
# Recovery 1: 7-26 [20] ->
# Startup 2: 1-4 [4] -> Active 2
# Active 2: 5-6 [2] -> Recovery 2
# 	Sour 2: 5-6
# 	Tipper 2: 5-6
# Recovery 2: 7-26 [20] ->
# Startup 3: 1-4 [4] -> Active 3
# Active 3: 5-6 [2] -> Recovery 3
# 	Sour 3: 5-6
# 	Tipper 3: 5-6
# Recovery 3: 7-26 [20] ->
# Startup Final: 1-30 [30] -> Active Final
# Active Final: 31-32 [2] -> Recovery Final
# 	Finisher: 31-32
# Recovery Final: 33-92 [60] ->
#
#
# = Etalus =
#
# ====Jab====
# Startup 1: 1-5 [5] -> Active 1
# Active 1: 6-7 [2] -> Recovery 1
# 	Hit 1: 6-7
# Recovery 1: 8-25 [18] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 12+
# 		ENDLAG: 4+
# Startup 2: 1-5 [5] -> Active 2
# Active 2: 6-7 [2] -> Recovery 2
# 	Hit 2: 6-7
# Recovery 2: 8-20 [13] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 12+
# 		ENDLAG: 4+
# Startup 3: 1-6 [6] -> Active 3
# Active 3: 7-9 [3] -> Recovery 3
# 	Hit 3 Sweet: 7-9
# 	Hit 3 Sour: 7
# Recovery 3: 10-28 [19] ->
#
# ====Ftilt====
# Startup: 1-8 [8] -> Active 1
# Active 1: 9-10 [2] -> Between 1
# 	Hit 1: 9-10
# Between 1: 11-11 [1] -> Active 2
# Active 2: 12-13 [2] -> Between 2
# 	Hit 2: 12-13
# Between 2: 14-14 [1] -> Active 3
# Active 3: 15-17 [3] -> Recovery
# 	Hit 3: 15-17
# Recovery: 18-37 [20] ->
#
# ====Utilt====
# Startup: 1-9 [9] -> Active
# Active: 10-12 [3] -> Recovery
# 	Sweet: 10-12
# Recovery: 13-39 [27] ->
#
# ====Dtilt====
# Startup 1: 1-6 [6] -> Active 1
# Active 1: 7-9 [3] -> Recovery 1
# 	Hit 1: 7-9
# Recovery 1: 10-25 [16] ->
# 	[CANCEL: DtiltPressed>
# 		IASA: 14+
# 		ENDLAG: 4+
# Startup 2: 1-4 [4] -> Active 2
# Active 2: 5-7 [3] -> Recovery 2
# 	Hit 2: 5-7
# Recovery 2: 8-23 [16] ->
#
# ====Dattack====
# Startup: 1-8 [8] -> Active 1
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# Active 1: 9-11 [3] -> Active Loop
# 	[CANCEL: Aerial>
# 		IASA: 9+
# 		ENDLAG: 0+
# 	[CANCEL: JumpPressed>
# 		IASA: 10+
# 		ENDLAG: 1+
# 	Early: 9-11
# Active Loop: 12-23 [12] -> Active Loop
# 	[CANCEL: Aerial>
# 		IASA: 24+
# 		ENDLAG: 0+
# 	[CANCEL: JumpPressed>
# 		IASA: 24+
# 		ENDLAG: 0+
# 	Late: 24-35
# Recovery: 1-18 [18] ->
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# Jump Cancel Squat: 1-4 [4] -> Jump Cancel
# Jump Cancel: 5-24 [20] ->
# 	[CANCEL: Grounded>
# 		IASA: 6+
# 		ENDLAG: 1+
#
# ====Fstrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-17 [7] -> Active 1
# Active 1: 18-23 [6] -> Between Hits
# 	Hit 1 Back: 18-23
# 	Hit 1 Front: 18-23
# Between Hits: 24-25 [2] -> Active 2
# Active 2: 26-28 [3] -> Recovery
# 	Hit 2: 26-28
# Recovery: 29-67 [39] ->
#
# ====Ustrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-18 [8] -> Active 1
# Active 1: 19-20 [2] -> Between Hits
# 	Hit 1: 19-20
# Between Hits: 21-22 [2] -> Active 2
# Active 2: 23-26 [4] -> Recovery
# 	Hit 2: 23-26
# Recovery: 27-64 [38] ->
#
# ====Dstrong====
# Pre-Charge: 1-8 [8] -> Charge
# Post-Charge: 9-14 [6] -> Active 1
# Active 1: 15-16 [2] -> Active 2
# 	Early: 15-16
# Active 2: 17-18 [2] -> Recovery
# 	Sour: 17-18
# 	Mid: 17-18
# 	Sweet: 17-18
# Recovery: 19-58 [40] ->
#
# ====Nair====
# Startup: 1-5 [5] -> Active
# Active: 6-27 [22] -> Recovery
# 	Early: 6-7
# 	Late: 8-27
# Recovery: 28-35 [8] ->
#
# ====Fair====
# Startup: 1-7 [7] -> Blocking
# Blocking: 8-32 [25] -> Block Recovery
# 	[CANCEL: AttackAndStrongReleased>
# 		IASA: 11+
# 		ENDLAG: 3+
# Block Recovery: 33-37 [5] ->
#
# ====Bair====
# Startup: 1-9 [9] -> Active
# Active: 10-12 [3] -> Recovery
# 	Bair: 10-12
# Recovery: 13-30 [18] ->
#
# ====Dair====
# Startup: 1-12 [12] -> Active 1
# Active 1: 13-15 [3] -> Between 1
# 	Multihit: 13-15
# Between 1: 16-17 [2] -> Active 2
# Active 2: 18-20 [3] -> Between 2
# 	Multihit: 18-20
# Between 2: 21-24 [4] -> Active 3
# Active 3: 25-27 [3] -> Recovery
# 	Final: 25-27
# Recovery: 28-48 [21] ->
#
# ====Uair====
# Startup: 1-8 [8] -> Active
# Active: 9-12 [4] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: 0+
# 	Hit Object: 9-12
# Recovery: 13-36 [24] ->
# Throw Startup: 1-22 [22] -> Throw Active
# Throw Active: 23-23 [1] -> Throw Recovery
# Throw Recovery: 24-33 [10] ->
#
# ====Nspecial====
# Startup: 1-63 [63] -> Active
# Active: 64-67 [4] -> Recovery
# 	Base: 65-67
# 	Top: 64-65
# Recovery: 68-92 [25] ->
#
# ====Fspecial====
# Startup: 1-11 [11] -> Active
# Active: 12-22 [11] -> Recovery
# Recovery: 23-36 [14] ->
#
# ====Uspecial====
# Startup: 1-10 [10] -> Charging
# Launch Startup: 11-12 [2] -> Active
# Active: 13-14 [2] -> Launch
# 	Spike: 13-14
# Launch: 15-46 [32] ->
# 	[CANCEL: Grounded>
# 		IASA: 16+
# 		ENDLAG: 1+
#
# ====Dspecial====
# Startup: 1-13 [13] -> Rising Active
# 	[CANCEL: Aerial>
# 		IASA: 1-1
# 		ENDLAG: 0-0
# Rising Active: 14-20 [7] -> Stalled
# 	Rising: 14-20
# Aerial Startup: 1-9 [9] -> Stalled
# Stalled: 10-25 [16] -> Falling Active
# Falling Active: 26-37 [12] -> Falling Active
# 	[CANCEL: Grounded>
# 		IASA: 38+
# 		ENDLAG: 0+
# 	Falling: 38-49
# Landing Active: 1-8 [8] -> Recovery
# 	Landing: 1-8
# Recovery: 9-40 [32] ->
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====Fthrow====
# Startup: 1-12 [12] -> Active
# Active: 13-32 [20] -> Recovery
# 	Roll: 13-32
# Recovery: 33-47 [15] ->
#
# ====Bthrow====
# Startup: 1-18 [18] -> Active
# Active: 19-19 [1] -> Recovery
# Recovery: 20-47 [28] ->
#
# ====Uthrow====
# Startup: 1-12 [12] -> Active
# Active: 13-15 [3] -> Recovery
# 	Uthrow: 13-15
# Recovery: 16-45 [30] ->
#
# ====Dthrow====
# Startup: 1-38 [38] -> Active
# Active: 39-39 [1] -> Recovery
# 	Slam: 39
# Recovery: 40-73 [34] ->
#
# ====LedgeAttack====
# Startup: 1-9 [9] -> Active 1
# Active 1: 10-11 [2] -> Between 1
# 	Lattack: 10-11
# Between 1: 12-19 [8] -> Active 2
# Active 2: 20-21 [2] -> Between 2
# 	Lattack: 20-21
# Between 2: 22-29 [8] -> Active 3
# Active 3: 30-31 [2] -> Recovery
# 	Lattack: 30-31
# Recovery: 32-55 [24] ->
#
# ====LedgeSpecial====
# Startup: 1-10 [10] -> Spawn Ice
# Spawn Ice: 11-11 [1] -> Startup 2
# Startup 2: 12-21 [10] -> Active 1
# Active 1: 22-23 [2] -> Active Loop
# 	[CANCEL: OnPlayerHit>
# 		IASA: 22+
# 		ENDLAG: 0+
# 	Slide: 22-23
# Active Loop: 24-38 [15] -> Active Loop
# 	[CANCEL: OnPlayerHit>
# 		IASA: 39+
# 		ENDLAG: 0+
# 	Slide: 39-53
# Recovery: 1-38 [38] ->
#
# ====GetupAttack====
# Startup: 1-18 [18] -> Active
# Active: 19-26 [8] -> Recovery
# 	Gattack: 19-26
# Recovery: 27-45 [19] ->
#
# ====GetupSpecial====
# Pre-Charge: 1-20 [20] -> Charge
# Post-Charge: 21-30 [10] -> Active
# Active: 31-40 [10] -> Recovery
# 	Gspecial: 31-40
# Recovery: 41-70 [30] ->
#
# ====Fair2====
# Placeholder to avoid autocancels: 1-0 [0] ->
# Punch Startup: 1-10 [10] -> Active
# Active: 11-14 [4] -> Recovery
# 	Fair: 11-14
# Recovery: 15-37 [23] ->
#
# ====Intro====
# Intro: 1-120 [120] ->
#
# ====Taunt1====
# Startup: 1-70 [70] -> Loop
# Loop: 71-240 [170] -> Loop
# 	[CANCEL: TauntReleased>
# 		IASA: 241+
# 		ENDLAG: 0+
# Recovery: 1-25 [25] ->
#
# ====Taunt2====
# Taunt: 1-95 [95] ->
#
# ====IceHalo====
# Spawn: 1-30 [30] -> Idle
# Idle: 31-630 [600] ->
# Attack Startup: 1-15 [15] -> Active
# Active: 16-16 [1] ->
# 	Freeze: 16
#
# ====IceShard====
# Horizontal Active: 1-15 [15] -> Despawn
# 	Horizontal: 1-15
# Vertical Active: 1-15 [15] -> Despawn
# 	Vertical: 1-15
# Despawn: 16-18 [3] ->
#
# ====Icicle====
# Startup: 1-7 [7] -> Active
# Active: 8-307 [300] ->
# 	Fspecial: 8-307
# Landing Active: 1-1 [1] ->
# 	Fspecial: 1
#
#
# = Fleet =
#
# ====Jab====
# Startup 1: 1-5 [5] -> Active 1
# Active 1: 6-7 [2] -> Recovery 1
# 	Jab 1: 6-8
# Recovery 1: 8-21 [14] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 11+
# 		ENDLAG: 3+
# Startup 2: 1-4 [4] -> Active 2
# Active 2: 5-7 [3] -> Recovery 2
# 	Jab 2: 5-7
# Recovery 2: 8-22 [15] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 10+
# 		ENDLAG: 2+
# Startup 3: 1-5 [5] -> Active 3
# Active 3: 6-9 [4] -> Recovery 3
# 	Jab Final Sour: 6-9
# 	Jab Final: 6-9
# Recovery 3: 10-30 [21] ->
#
# ====Ftilt====
# Startup: 1-10 [10] -> Active
# Active: 11-13 [3] -> Recovery
# 	Ftilt: 11-13
# Recovery: 14-33 [20] ->
#
# ====Utilt====
# Startup: 1-8 [8] -> Active 1
# Active 1: 9-11 [3] -> Between 1
# 	Multihit: 9-11
# Between 1: 12-12 [1] -> Active 2
# Active 2: 13-14 [2] -> Between 2
# 	Multihit: 13-15
# Between 2: 15-15 [1] -> Active 3
# Active 3: 16-17 [2] -> Between 3
# 	Multihit: 16-18
# Between 3: 18-18 [1] -> Active 4
# Active 4: 19-20 [2] -> Recovery
# 	Final Hit: 19-20
# Recovery: 21-35 [15] ->
#
# ====Dtilt====
# Startup: 1-9 [9] -> Active
# Active: 10-12 [3] -> Recovery
# 	Sweet: 10-12
# 	Sour: 10-12
# Recovery: 13-28 [16] ->
#
# ====Dattack====
# Startup: 1-8 [8] -> Active 1
# Active 1: 9-11 [3] -> Active 2
# 	Multi: 9-11
# Active 2: 12-14 [3] -> Active 3
# 	Multi: 12-14
# Active 3: 15-17 [3] -> Recovery
# 	Final: 15-17
# Recovery: 18-40 [23] ->
#
# ====Fstrong====
# Pre-Charge: 1-18 [18] -> Charge
# Post-Charge: 19-22 [4] -> Active
# Active: 23-23 [1] -> Recovery
# Recovery: 24-55 [32] ->
#
# ====Ustrong====
# Pre-Charge: 1-16 [16] -> Charge
# Post-Charge: 17-20 [4] -> Active
# Active: 21-21 [1] -> Recovery
# Recovery: 22-53 [32] ->
#
# ====Dstrong====
# Pre-Charge: 1-6 [6] -> Charge
# Post-Charge: 7-16 [10] -> Active
# Active: 17-32 [16] -> Recovery
# 	Early: 17-19
# 	Late: 20-32
# Recovery: 33-50 [18] ->
#
# ====Nair====
# Startup: 1-4 [4] -> Active
# Active: 5-20 [16] -> Recovery
# 	Early: 5-7
# 	Late: 8-24
# Recovery: 21-40 [20] ->
#
# ====Fair====
# Startup: 1-7 [7] -> Active 1
# Active 1: 8-10 [3] -> Between 1
# 	Multi: 8-10
# Between 1: 11-11 [1] -> Active 2
# Active 2: 12-14 [3] -> Between 2
# 	Multi: 12-14
# Between 2: 15-15 [1] -> Active 3
# Active 3: 16-18 [3] -> Between 3
# 	Multi: 16-18
# Between 3: 19-19 [1] -> Active 4
# Active 4: 20-21 [2] -> Recovery
# 	Final: 20-21
# Recovery: 22-41 [20] ->
#
# ====Bair====
# Startup: 1-9 [9] -> Active
# Active: 10-13 [4] -> Recovery
# 	Sweet: 10-12
# 	Sour: 10-12
# 	Reverse: 12-13
# Recovery: 14-37 [24] ->
#
# ====Dair====
# Startup: 1-17 [17] -> Active
# Active: 18-18 [1] -> Recovery
# Recovery: 19-47 [29] ->
#
# ====Uair====
# Startup: 1-11 [11] -> Active
# Active: 12-15 [4] -> Recovery
# 	Early: 12
# 	Late Sour: 13-15
# 	Late Sweet: 13-15
# Recovery: 16-40 [25] ->
#
# ====Nspecial====
# Startup: 1-8 [8] -> Recovery
# Recovery: 9-16 [8] ->
# Fail: 1-30 [30] ->
# Rummage Startup: 1-80 [80] -> Rummage Recovery
# Rummage Recovery: 81-100 [20] ->
# Cancel: 1-16 [16] ->
#
# ====Fspecial====
# Startup: 1-27 [27] -> Active
# Active: 28-28 [1] -> Recovery
# Recovery: 29-48 [20] ->
#
# ====Uspecial====
# Startup: 1-10 [10] -> Rising Active
# Rising Active: 11-12 [2] -> Rising Recovery
# 	Rising: 11-12
# Rising Recovery: 13-16 [4] -> Stalled
# Stalled: 17-29 [13] -> Launch Active
# Launch Active: 30-30 [1] -> Travel Active
# 	Travel: 30
# 	Launch: 30
# Travel Active: 31-44 [14] -> Recovery
# 	[CANCEL: Grounded>
# 		IASA: 32+
# 		ENDLAG: 1+
# 	Travel: 31-44
# Travel Grounded: 1-14 [14] -> Recovery
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# Recovery: 15-27 [13] -> Looping Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 14+
# 		ENDLAG: -1+
# Looping Special Fall: 28-57 [30] -> Looping Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 58+
# 		ENDLAG: 0+
# Special Land: 1-30 [30] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
#
# ====Dspecial====
# Startup: 1-8 [8] -> Dodge
# Dodge: 9-18 [10] -> Drawing Bow
# Drawing Bow: 19-30 [12] -> Active
# Active: 31-31 [1] -> Recovery
# Recovery: 32-73 [42] ->
# 	[CANCEL: Grounded>
# 		IASA: 32+
# 		ENDLAG: 0+
# Whiff Landing: 1-22 [22] ->
# 	[CANCEL: OnObjectHit>
# 		IASA: 1-1
# 		ENDLAG: 0-0
# Landing: 1-8 [8] ->
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Wait
# 	Pummel: 11
# Wait: 12-41 [30] -> Use Stamina
# Use Stamina: 42-42 [1] -> Recovery
# Recovery: 43-52 [10] ->
#
# ====Fthrow====
# Startup: 1-11 [11] -> Bow Active
# Bow Active: 12-12 [1] -> Drawing Bow
# 	Fthrow: 12
# Drawing Bow: 13-28 [16] -> Firing Active 1
# Firing Active 1: 29-29 [1] -> Between Shots 1
# Between Shots 1: 30-45 [16] -> Firing Active 2
# Firing Active 2: 46-46 [1] -> Between Shots 2
# Between Shots 2: 47-62 [16] -> Firing Active 3
# Firing Active 3: 63-63 [1] -> Recovery
# Recovery: 64-87 [24] ->
#
# ====Bthrow====
# Startup: 1-8 [8] -> Release
# Release: 9-9 [1] -> Drawing Bow
# Drawing Bow: 10-14 [5] -> Active
# Active: 15-15 [1] -> Recovery
# Recovery: 16-41 [26] ->
#
# ====Uthrow====
# Startup: 1-10 [10] -> Release
# Release: 11-11 [1] -> Drawing Bow
# Drawing Bow: 12-16 [5] -> Active
# Active: 17-17 [1] -> Recovery
# Recovery: 18-45 [28] ->
#
# ====Dthrow====
# Startup: 1-15 [15] -> Active
# Active: 16-16 [1] -> Recovery
# 	Shot: 16
# Recovery: 17-37 [21] ->
#
# ====LedgeAttack====
# Startup: 1-28 [28] -> Active
# Active: 29-31 [3] -> Recovery
# 	Lattack: 29-31
# Recovery: 32-55 [24] ->
#
# ====LedgeSpecial====
# Pre-Aim Startup: 1-30 [30] -> Aim Up
# Aim Back: 1-2 [2] -> Active Back
# Aim Up: 31-32 [2] -> Active Up
# Aim Forward: 1-2 [2] -> Active Forward
# Active Back: 3-3 [1] -> Recovery
# Active Up: 33-33 [1] -> Recovery
# Active Forward: 3-3 [1] -> Recovery
# Recovery: 4-29 [26] ->
#
# ====GetupAttack====
# Startup: 1-16 [16] -> Active
# Active: 17-25 [9] -> Recovery
# 	Gattack: 17-25
# Recovery: 26-50 [25] ->
#
# ====GetupSpecial====
# Startup: 1-22 [22] -> Active
# Active: 23-23 [1] -> Recovery
# Recovery: 24-60 [37] ->
#
# ====Intro====
# Ride: 1-56 [56] -> Land
# Land: 57-76 [20] -> Recovery
# Recovery: 77-120 [44] ->
#
# ====PummelSpecial_OLD====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====Taunt1====
# Startup: 1-56 [56] -> Loop
# Loop: 57-106 [50] -> Loop
# 	[CANCEL: TauntReleased>
# 		IASA: 107-107
# 		ENDLAG: 0-0
# Recovery: 1-52 [52] ->
#
# ====Taunt2====
# Whole Taunt: 1-90 [90] ->
#
# ====Apple====
# Fall: 1-30 [30] -> Fall
# Idle: 1-240 [240] -> Despawn
# 	None: 1-240
# Despawn: 241-300 [60] ->
# 	None: 241-480
#
# ====Arrow====
# Fstrong: 1-300 [300] ->
# 	Fstrong Early: 1-3
# 	Fstrong Mid: 4-8
# 	Fstrong Late: 9-300
# Ftilt 2: 1-300 [300] ->
# Ftilt 3: 1-300 [300] ->
# Ustrong: 1-70 [70] -> Ustrong Fall
# 	Ustrong Early: 1-2
# 	Ustrong Mid: 3-7
# 	Ustrong Late: 8-70
# Dair: 1-300 [300] ->
# 	Dair Early: 1-2
# 	Dair Late: 1-300
# Dspecial Ground: 1-300 [300] ->
# 	Dspecial: 1-300
# Dspecial Air: 1-300 [300] ->
# 	Dspecial: 1-300
# Uthrow: 1-300 [300] ->
# 	Uthrow: 1-300
# Bthrow1: 1-300 [300] ->
# 	Bthrow: 1-15
# 	Bthrow Late: 16-300
# Bthrow2: 1-300 [300] ->
# 	Bthrow: 1-15
# 	Bthrow Late: 16-300
# Bthrow3: 1-300 [300] ->
# 	Bthrow: 1-15
# 	Bthrow Late: 16-300
# Ledge Special: 1-300 [300] ->
# 	Lspecial: 1-300
# Stuck In Ground: 1-180 [180] ->
# 	None: 1-180
# Broken: 1-30 [30] ->
# Ustrong Fall: 71-370 [300] ->
# 	Ustrong Fall: 71-370
#
# ====HomingArrow====
# Fthrow Multihit: 1-30 [30] ->
# 	Multi: 1-30
# Fthrow Final: 1-30 [30] ->
# 	Multi: 1-30
# Uthrow: 1-30 [30] ->
# 	Uthrow: 1-30
#
# ====Meat====
# Fall: 1-30 [30] -> Fall
# Idle: 1-240 [240] -> Despawn
# 	None: 1-240
# Despawn: 241-300 [60] ->
# 	None: 241-480
# GSpecial Active: 1-300 [300] ->
# 	Gspecial: 1-300
#
# ====Peach====
# Fall: 1-30 [30] -> Fall
# Idle: 1-240 [240] -> Despawn
# 	None: 1-240
# Despawn: 241-300 [60] ->
# 	None: 241-480
#
# ====StaminaTornado====
# Startup 1: 1-60 [60] -> Startup 2
# Startup 2: 61-120 [60] -> Startup 3
# Startup 3: 121-180 [60] -> Active
# Active: 181-181 [1] ->
# 	Final: 181
#
# ====WindArrow====
# Active 1: 1-12 [12] -> Recovery 1
# 	Arrow Early: 1-8
# 	Arrow Late: 9-12
# Recovery 1: 13-22 [10] -> Tornado Startup
# Tornado Startup: 23-52 [30] -> Active 2
# Active 2: 53-112 [60] ->
# 	Tornado: 53-112
# 	None: 53-112
#
#
# = Forsburn =
#
# ====Jab====
# Startup 1: 1-6 [6] -> Active 1
# Active 1: 7-8 [2] -> Recovery 1
# 	Jab 1: 7-8
# Recovery 1: 9-24 [16] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 12+
# 		ENDLAG: 3+
# Startup 2: 1-5 [5] -> Active 2
# Active 2: 6-7 [2] -> Recovery 2
# 	Jab 2: 6-7
# Recovery 2: 8-25 [18] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 12+
# 		ENDLAG: 4+
# Startup 3: 1-8 [8] -> Active 3
# Active 3: 9-11 [3] -> Recovery 3
# 	Jab 3: 9-11
# Recovery 3: 12-33 [22] ->
#
# ====Ftilt====
# Startup: 1-6 [6] -> Active 1
# Active 1: 7-8 [2] -> Between 1
# 	Multihit: 7-8
# Between 1: 9-10 [2] -> Active 2
# Active 2: 11-12 [2] -> Between 2
# 	Multihit: 11-12
# Between 2: 13-14 [2] -> Active 3
# Active 3: 15-17 [3] -> Recovery
# 	Final: 15-17
# Recovery: 18-33 [16] ->
#
# ====Utilt====
# Startup: 1-9 [9] -> Active 1
# Active 1: 10-11 [2] -> Between 1
# 	Multihit: 10-11
# 	Multihit High: 10-11
# Between 1: 12-13 [2] -> Active 2
# Active 2: 14-15 [2] -> Between 2
# 	Multihit: 14-15
# 	Multihit High: 14-15
# Between 2: 16-17 [2] -> Active 3
# Active 3: 18-19 [2] -> Recovery
# 	Final: 18-19
# Recovery: 20-34 [15] ->
#
# ====Dtilt====
# Startup: 1-6 [6] -> Active
# Active: 7-9 [3] -> Recovery
# 	Sour: 7-9
# 	Sweet: 7-9
# Recovery: 10-27 [18] ->
#
# ====Dattack====
# Startup: 1-8 [8] -> Active
# Active: 9-12 [4] -> Recovery
# 	Sour: 9-10
# 	Sweet: 9-10
# 	Top: 11-12
# Recovery: 13-38 [26] ->
#
# ====Fstrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-14 [4] -> Active
# Active: 15-19 [5] -> Recovery
# 	Cloak Inner: 15-19
# 	Cloak Mid: 15-19
# 	Cloak Outer: 15-19
# Recovery: 20-46 [27] ->
# 	[CANCEL: FstrongPressed>
# 		IASA: 30+
# 		ENDLAG: 10+
# Dagger Startup: 1-6 [6] -> Dagger Active
# Dagger Active: 7-9 [3] -> Dagger Recovery
# 	Dagger: 7-9
# Dagger Recovery: 10-39 [30] ->
#
# ====Ustrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-14 [4] -> Active
# Active: 15-20 [6] -> Recovery
# 	Cloak Inner: 15-20
# 	Cloak Outer Low: 15, 19-15, 20-15
# 	Cloak Outer High: 15-20
# Recovery: 21-43 [23] ->
# 	[CANCEL: UstrongPressed>
# 		IASA: 31+
# 		ENDLAG: 10+
# Dagger Startup: 1-4 [4] -> Dagger Active
# Dagger Active: 5-7 [3] -> Dagger Recovery
# 	Dagger: 5-7
# 	Dagger Sour: 5-7
# Dagger Recovery: 8-37 [30] ->
#
# ====Dstrong====
# Pre-Charge: 1-4 [4] -> Charge
# Post-Charge: 5-8 [4] -> Active
# Active: 9-10 [2] -> Recovery
# 	Dstrong: 9-10
# Recovery: 11-50 [40] ->
#
# ====Nair====
# Startup: 1-6 [6] -> Active 1
# Active 1: 7-9 [3] -> Between 1
# 	Hit 1 Base: 7-9
# 	Hit 1 Tip: 7-9
# Between 1: 10-10 [1] -> Active 2
# Active 2: 11-13 [3] -> Between 2
# 	Hit 2: 11-13
# Between 2: 14-14 [1] -> Active 3
# Active 3: 15-17 [3] -> Recovery
# 	Hit 3: 15-17
# Recovery: 18-33 [16] ->
#
# ====Fair====
# Startup: 1-6 [6] -> Active
# Active: 7-9 [3] -> Recovery
# 	Fair: 7-9
# Recovery: 10-20 [11] ->
#
# ====Bair====
# Startup: 1-13 [13] -> Active
# Active: 14-27 [14] -> Recovery
# 	Sweet: 14-15
# 	Sour: 16-27
# Recovery: 28-39 [12] ->
#
# ====Dair====
# Startup: 1-11 [11] -> Active
# Active: 12-16 [5] -> Recovery
# 	Spike: 14-16
# 	Sweet: 12-15
# Recovery: 17-37 [21] ->
#
# ====Uair====
# Startup: 1-7 [7] -> Active
# Active: 8-17 [10] -> Recovery
# 	Early Base: 8-11
# 	Early Tip: 8-11
# 	Late Base: 12-17
# 	Late Tip: 12-17
# Recovery: 18-37 [20] ->
#
# ====Nspecial====
# Startup: 1-9 [9] -> Recovery
# 	[CANCEL: CharacterSpecific2>
# 		IASA: 10+
# 		ENDLAG: 9+
# Recovery: 10-30 [21] ->
# Empowered Release: 1-1 [1] -> Empowered Recovery
# Empowered Recovery: 2-11 [10] ->
#
# ====Fspecial====
# Startup: 1-20 [20] -> Splitting
# 	[CANCEL: CharacterSpecific3>
# 		IASA: 21+
# 		ENDLAG: 20+
# Splitting: 21-28 [8] -> Recovery
# Recovery: 29-35 [7] ->
# Fail Recovery: 1-11 [11] ->
#
# ====Uspecial====
# Startup 1: 1-18 [18] -> Travel
# Travel: 19-38 [20] -> Startup 2
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 39+
# 		ENDLAG: 20+
# Startup 2: 39-43 [5] -> Active
# Active: 44-48 [5] -> Recovery Start
# 	Uspecial: 44-48
# Recovery Start: 49-58 [10] -> Grounded Recovery
# 	[CANCEL: Aerial>
# 		IASA: 59+
# 		ENDLAG: 10+
# Grounded Recovery: 59-78 [20] ->
# 	[CANCEL: Aerial>
# 		IASA: 59+
# 		ENDLAG: 0+
# Aerial Recovery: 1-20 [20] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
# Special Fall: 21-40 [20] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 41+
# 		ENDLAG: 0+
# Special Land: 1-10 [10] ->
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# In-Smoke Recovery: 1-0 [0] ->
#
# ====Dspecial====
# Consume Startup: 1-8 [8] -> Consume Fail
# 	[CANCEL: CharacterSpecific3>
# 		IASA: 1+
# 		ENDLAG: 0+
# 	[CANCEL: CharacterSpecific2>
# 		IASA: 1-1
# 		ENDLAG: 0-0
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 9+
# 		ENDLAG: 8+
# Consume: 1-10 [10] -> Consume Recovery
# Consume Recovery: 11-34 [24] ->
# Consume Fail: 9-13 [5] ->
# Combust Startup: 1-10 [10] -> Combust Active
# Combust Active: 11-15 [5] -> Combust Recovery
# 	Sweet: 11-15
# 	Sour: 11-15
# Combust Recovery: 16-35 [20] ->
# Detonate Command: 1-8 [8] ->
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active 1
# Active 1: 11-12 [2] -> Active 2
# 	Pummel: 11
# Active 2: 13-14 [2] -> Active 3
# 	Pummel: 13
# Active 3: 15-16 [2] -> Recovery
# 	Pummel: 15
# Recovery: 17-36 [20] ->
#
# ====Fthrow====
# Startup: 1-30 [30] -> Active
# Active: 31-31 [1] -> Recovery
# 	Fthrow: 31
# Recovery: 32-56 [25] ->
#
# ====Bthrow====
# Startup: 1-30 [30] -> Active
# Active: 31-31 [1] -> Recovery
# 	Bthrow: 31
# Recovery: 32-57 [26] ->
#
# ====Uthrow====
# Startup: 1-17 [17] -> Active
# Active: 18-18 [1] -> Recovery
# Recovery: 19-51 [33] ->
#
# ====Dthrow====
# Startup: 1-13 [13] -> Active
# Active: 14-14 [1] -> Recovery
# 	Dthrow: 14
# Recovery: 15-33 [19] ->
#
# ====LedgeAttack====
# Startup: 1-25 [25] -> Active
# Active: 26-29 [4] -> Recovery
# 	Lattack: 26-29
# Recovery: 30-55 [26] ->
#
# ====LedgeSpecial====
# Startup: 1-7 [7] -> Leap
# Leap: 8-20 [13] -> Throw Startup
# 	[CANCEL: ForwardDown>
# 		IASA: 21+
# 		ENDLAG: 13+
# 	[CANCEL: SpecialDown>
# 		IASA: 21+
# 		ENDLAG: 13+
# Throw Startup: 21-40 [20] -> Throw Recovery
# 	[CANCEL: CharacterSpecific4>
# 		IASA: 41-41
# 		ENDLAG: 20-20
# Throw Recovery: 41-85 [45] ->
# 	[CANCEL: Grounded>
# 		IASA: 41+
# 		ENDLAG: 0+
# Throw Landing: 1-20 [20] ->
# Thrown Startup: 1-20 [20] -> Thrown Active
# 	[CANCEL: CharacterSpecific4>
# 		IASA: 21-21
# 		ENDLAG: 20-20
# Thrown Active: 21-34 [14] -> Thrown Active
# 	[CANCEL: Grounded>
# 		IASA: 35+
# 		ENDLAG: 0+
# 	Travel: 35-48
# Landing Active: 1-3 [3] -> Recovery
# 	Landing: 1-3
# Recovery: 4-28 [25] ->
# Throw Recovery Clone: 1-25 [25] ->
# Thrown Active Clone: 1-14 [14] -> Explosion
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
# 	Travel: 1-14
# Explosion: 15-18 [4] -> Explosion Recovery
# 	Explosion: 15-18
# Explosion Recovery: 19-32 [14] ->
#
# ====GetupAttack====
# Startup: 1-17 [17] -> Active 1
# Active 1: 18-20 [3] -> Between Hits
# 	Gattack: 18-20
# Between Hits: 21-25 [5] -> Active 2
# Active 2: 26-28 [3] -> Recovery
# 	Gattack: 26-28
# Recovery: 29-50 [22] ->
#
# ====GetupSpecial====
# Startup 1: 1-23 [23] -> Startup 2
# Startup 2: 24-28 [5] -> Active
# Active: 29-33 [5] -> Recovery
# 	Gspecial: 29-33
# Recovery: 34-73 [40] ->
# 	[CANCEL: CharacterSpecific4>
# 		IASA: 34-34
# 		ENDLAG: 0-0
# Clone Recovery: 1-14 [14] ->
#
# ====Dspecial_Clone====
# Detonate Startup: 1-4 [4] -> Detonate Active
# 	[CANCEL: CharacterSpecific2>
# 		IASA: 1-1
# 		ENDLAG: 0-0
# Detonate Active: 5-8 [4] -> Recovery
# 	Normal: 5-8
# Empowered Detonate Startup: 1-9 [9] -> Empowered Detonate Active
# Empowered Detonate Active: 10-14 [5] -> Recovery
# 	Empowered Sweet: 10-14
# 	Empowered Sour: 10-14
# Recovery: 15-28 [14] ->
#
# ====Fspecial_Clone====
# Wait Startup: 1-6 [6] -> Wait For Clone
# Wait For Clone: 7-102 [96] -> Wait For Clone
# 	[CANCEL: SpecialReleased>
# 		IASA: 103+
# 		ENDLAG: 0+
# Wait Recovery: 1-10 [10] ->
# Startup: 1-16 [16] -> Launch
# Launch: 17-21 [5] -> Active
# Active: 22-28 [7] -> Stalled Recovery
# 	Final: 22-28
# Stalled Recovery: 29-36 [8] -> Recovery
# Recovery: 37-56 [20] ->
# Clone Startup: 1-16 [16] -> Clone Recovery
# Clone Recovery: 17-46 [30] ->
# 	[CANCEL: CharacterSpecific2>
# 		IASA: 17-17
# 		ENDLAG: 0-0
# Super Clone Recovery: 1-30 [30] ->
# 	[CANCEL: Grounded>
# 		IASA: 21+
# 		ENDLAG: 20+
#
# ====Intro====
# InSmoke: 1-47 [47] -> Appears
# Appears: 48-120 [73] ->
#
# ====Taunt1====
# FullTaunt: 1-74 [74] ->
#
# ====Taunt2====
# FullTaunt: 1-102 [102] ->
#
# ====SmokeCloud====
# Inactive: 1-10 [10] -> Activating
# Activating: 11-20 [10] -> Idle
# Idle: 21-80 [60] -> Idle
# Destroy: 1-20 [20] ->
#
#
# = Kragg =
#
# ====Jab====
# Startup 1: 1-5 [5] -> Active 1
# Active 1: 6-7 [2] -> Recovery 1
# 	Jab 1 KB: 6-7
# Recovery 1: 8-23 [16] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 10+
# 		ENDLAG: 2+
# Startup 2: 1-5 [5] -> Active 2
# Active 2: 6-7 [2] -> Recovery 2
# 	Jab 2 KB: 6-7
# Recovery 2: 8-25 [18] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 10+
# 		ENDLAG: 2+
# Startup 3: 1-5 [5] -> Active 3
# Active 3: 6-8 [3] -> Recovery 3
# 	Jab 3 KB: 6-8
# Recovery 3: 9-34 [26] ->
#
# ====Ftilt====
# Startup: 1-11 [11] -> Active
# Active: 12-14 [3] -> Recovery
# 	Ftilt KB: 12-14
# Recovery: 15-32 [18] ->
#
# ====Utilt====
# Startup: 1-7 [7] -> Active 1
# Active 1: 8-9 [2] -> Between Hits
# 	Hit 1: 8-9
# Between Hits: 10-11 [2] -> Active 2
# Active 2: 12-15 [4] -> Recovery
# 	Hit 2: 12-15
# Recovery: 16-36 [21] ->
#
# ====Dtilt====
# Startup: 1-5 [5] -> Active
# Active: 6-8 [3] -> Recovery
# 	Dtilt KB: 6-8
# Recovery: 9-23 [15] ->
#
# ====Dattack====
# Startup: 1-9 [9] -> Active
# Active: 10-17 [8] -> Recovery
# 	Dattack KB: 10-17
# Recovery: 18-43 [26] ->
#
# ====Fstrong====
# Pre-Charge: 1-12 [12] -> Charge
# Post-Charge: 13-24 [12] -> Active
# Active: 25-29 [5] -> Recovery
# 	Fstrong KB: 25-29
# Recovery: 30-63 [34] ->
#
# ====Ustrong====
# Pre-Charge: 1-8 [8] -> Charge
# Post-Charge: 9-16 [8] -> Active
# Active: 17-21 [5] -> Recovery
# 	Early: 17-20
# 	Late: 20-21
# Recovery: 22-51 [30] ->
#
# ====Dstrong====
# Pre-Charge: 1-4 [4] -> Charge
# Post-Charge: 5-12 [8] -> Active
# Active: 13-18 [6] -> Recovery
# 	Sweetspot: 13-15
# 	Sourspot: 13-15
# Recovery: 19-51 [33] ->
#
# ====Nair====
# Startup: 1-6 [6] -> Active 1
# Active 1: 7-8 [2] -> Between 1
# 	Hit 1: 7-8
# Between 1: 9-10 [2] -> Active 2
# Active 2: 11-12 [2] -> Between 2
# 	Hit 2: 11-12
# Between 2: 13-14 [2] -> Active 3
# Active 3: 15-16 [2] -> Between 3
# 	Hit 3: 15-16
# Between 3: 17-18 [2] -> Active 4
# Active 4: 19-21 [3] -> Recovery
# 	Hit 4: 19-21
# Recovery: 22-33 [12] ->
#
# ====Fair====
# Startup: 1-12 [12] -> Active
# Active: 13-18 [6] -> Recovery
# 	Sweet: 13-14
# 	Sour: 15-18
# Recovery: 19-38 [20] ->
#
# ====Bair====
# Startup: 1-7 [7] -> Active
# Active: 8-15 [8] -> Recovery
# 	Early: 8-10
# 	Late: 11-15
# Recovery: 16-31 [16] ->
#
# ====Dair====
# Startup: 1-13 [13] -> Active
# Active: 14-16 [3] -> Recovery
# 	Dair KB: 14-16
# Recovery: 17-36 [20] ->
#
# ====Uair====
# Startup: 1-12 [12] -> Active
# Active: 13-15 [3] -> Recovery
# 	Sourspot: 13
# 	Sweetspot: 14-15
# Recovery: 16-40 [25] ->
#
# ====Nspecial====
# Startup: 1-6 [6] -> Rock Detection
# Rock Detection: 7-15 [9] -> Active
# 	None: 7-15
# Active: 16-17 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 15+
# 		ENDLAG: -1+
# 	None: 16-17
# Recovery: 18-45 [28] ->
# Hit Player: 1-16 [16] ->
# Rock Grab: 1-8 [8] ->
# Rock Pull: 1-20 [20] -> Rock Pull Recovery
# Rock Pull Recovery: 21-27 [7] ->
#
# ====Fspecial====
# Startup: 1-14 [14] -> Active
# 	[CANCEL: ShieldPressed>
# 		IASA: 1+
# 		ENDLAG: 0+
# Active: 15-30 [16] -> Active
# 	[CANCEL: DoubleJumpPressed>
# 		IASA: 30+
# 		ENDLAG: -1+
# 	Rolling KB: 31-46
# Recovery: 1-32 [32] ->
# 	[CANCEL: DoubleJumpPressed>
# 		IASA: 0+
# 		ENDLAG: -1+
# Turnaround: 1-18 [18] -> Active
# 	[CANCEL: DoubleJumpPressed>
# 		IASA: 0+
# 		ENDLAG: -1+
# Cancel: 1-24 [24] -> Special Fall
# Special Fall: 25-40 [16] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 41+
# 		ENDLAG: 0+
# Special Land: 1-28 [28] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# Jump Cancel Squat: 1-4 [4] -> Jump Cancel
# Jump Cancel: 5-30 [26] ->
# 	[CANCEL: Grounded>
# 		IASA: 6+
# 		ENDLAG: 1+
# Armored Hit: 1-15 [15] -> Active
#
# ====Uspecial====
# Startup: 1-13 [13] -> Summoning Pillar
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 14+
# 		ENDLAG: 13+
# Summoning Pillar: 14-25 [12] -> Recovery
# Recovery: 26-55 [30] ->
# Special Fall Start: 1-16 [16] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
# Special Fall: 17-40 [24] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 41+
# 		ENDLAG: 0+
# Special Land: 1-28 [28] ->
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
#
# ====Dspecial====
# Startup: 1-19 [19] -> Summoning
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# 	[CANCEL: CharacterSpecific2>
# 		IASA: 10+
# 		ENDLAG: 9+
# Summoning: 20-22 [3] -> Recovery
# Recovery: 23-45 [23] ->
# 	[CANCEL: JumpPressed>
# 		IASA: 36+
# 		ENDLAG: 13+
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====Fthrow====
# Startup: 1-13 [13] -> Active
# Active: 14-14 [1] -> Recovery
# 	Fthrow: 14
# Recovery: 15-35 [21] ->
#
# ====Bthrow====
# Startup: 1-22 [22] -> Active
# Active: 23-23 [1] -> Recovery
# Recovery: 24-53 [30] ->
#
# ====Uthrow====
# Startup: 1-16 [16] -> Rising
# Rising: 17-32 [16] -> Falling
# Falling: 33-48 [16] -> Active
# 	[CANCEL: Grounded>
# 		IASA: 32+
# 		ENDLAG: -1+
# Active: 49-49 [1] -> Recovery
# 	Uthrow: 49
# Recovery: 50-79 [30] ->
# 	[CANCEL: Aerial>
# 		IASA: 50+
# 		ENDLAG: 0+
# Aerial Recovery: 1-20 [20] ->
#
# ====Dthrow====
# Startup: 1-16 [16] -> Active
# Active: 17-17 [1] -> Recovery
# 	Dthrow: 17
# Recovery: 18-31 [14] ->
#
# ====LedgeAttack====
# Startup: 1-28 [28] -> Active
# Active: 29-30 [2] -> Recovery
# 	Lattack: 29-30
# Recovery: 31-55 [25] ->
#
# ====LedgeSpecial====
# Startup: 1-45 [45] -> Active
# Active: 46-48 [3] -> Recovery
# 	Lspecial: 46-48
# Recovery: 49-88 [40] ->
#
# ====GetupAttack====
# Startup: 1-10 [10] -> Active
# Active: 11-18 [8] -> Recovery
# 	Gattack: 11-18
# Recovery: 19-50 [32] ->
#
# ====GetupSpecial====
# Startup: 1-30 [30] -> Active 1
# Active 1: 31-32 [2] -> Active 2
# 	[CANCEL: None>
# 		IASA: 30+
# 		ENDLAG: -1+
# 	Hit 1: 31-32
# Active 2: 33-35 [3] -> Recovery
# 	Hit 2: 33-35
# Recovery: 36-60 [25] ->
# Recovery (No Rock): 1-35 [35] ->
#
# ====DspecialAir====
# Startup: 1-19 [19] -> Active
# 	[CANCEL: Grounded>
# 		IASA: 1-7
# 		ENDLAG: 0-6
# Active: 20-22 [3] -> Recovery
# 	Spike: 20-22
# Recovery: 23-44 [22] ->
#
# ====Intro====
# Full Intro: 1-120 [120] ->
#
# ====Rock_Dthrow====
# Startup: 1-8 [8] -> Recovery
# Recovery: 9-20 [12] ->
#
# ====Rock_Fthrow====
# Startup: 1-8 [8] -> Recovery
# Recovery: 9-20 [12] ->
#
# ====Rock_Nthrow====
# Startup: 1-8 [8] -> Recovery
# Recovery: 9-20 [12] ->
#
# ====Rock_Uthrow====
# Startup: 1-8 [8] -> Recovery
# Recovery: 9-20 [12] ->
#
# ====Taunt1====
# Startup: 1-12 [12] -> Active
# Active: 13-15 [3] -> Recovery
# 	Taunt Spike: 13-15
# Recovery: 16-72 [57] ->
#
# ====Taunt2====
# RightShoulder: 1-22 [22] -> LeftShoulder
# LeftShoulder: 23-44 [22] -> FistPound
# FistPound: 45-66 [22] -> Recovery
# Recovery: 67-89 [23] ->
#
# ====Earthquake====
# Active: 1-180 [180] ->
# 	Earthquake KB: 1-180
#
# ====EarthSpike1====
# Delay: 1-0 [0] -> Startup
# Startup: 1-3 [3] -> Active
# Active: 4-13 [10] -> Recovery
# 	First Spike: 4-13
# Recovery: 14-20 [7] ->
#
# ====EarthSpike2====
# Delay: 1-9 [9] -> Startup
# Startup: 10-12 [3] -> Active
# Active: 13-22 [10] -> Recovery
# 	Second Spike: 13-22
# Recovery: 23-29 [7] ->
#
# ====EarthSpike3====
# Delay: 1-18 [18] -> Startup
# Startup: 19-21 [3] -> Active
# Active: 22-31 [10] -> Recovery
# 	Final Spike: 22-31
# Recovery: 32-38 [7] ->
#
# ====Pillar====
# Rising: 1-12 [12] -> Stable
# 	Grounded: 1-12
# 	Aerial: 1-12
# Stable: 13-72 [60] -> Idle
# Idle: 73-132 [60] -> Idle
# Falling: 1-20 [20] -> Idle
#
# ====Rock====
# Picked Up: 1-60 [60] -> Picked Up
# Idle: 1-60 [60] -> Idle
# Nthrown: 1-300 [300] ->
# 	Nthrow KB: 1-300
# Fthrown: 1-300 [300] ->
# 	Fthrow KB: 1-300
# Uthrown: 1-300 [300] ->
# 	Uthrow KB: 1-300
# Moving Down: 1-300 [300] ->
# 	Dthrow KB: 1-300
# Rebound: 1-300 [300] ->
# Dropped: 1-300 [300] ->
#
# ====RockShard====
# Shard 1: 1-120 [120] ->
# 	Shard KB: 2-121
# Shard 2: 1-120 [120] ->
# 	Shard KB: 2-121
# Shard 3: 1-120 [120] ->
# 	Shard KB: 2-121
# Shard 4: 1-120 [120] ->
# 	Shard KB: 2-121
# Shard 5: 1-120 [120] ->
# 	Shard KB: 2-121
# Shard 6: 1-120 [120] ->
# 	Shard KB: 2-121
# Shard 7: 1-120 [120] ->
# 	Shard KB: 2-121
#
#
# = Loxodont =
#
# ====Jab====
# Startup 1: 1-7 [7] -> Active 1
# Active 1: 8-10 [3] -> Recovery 1
# 	Jab 1 Sour: 8-10
# 	Jab 1 Sweet: 8-10
# Recovery 1: 11-29 [19] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 14+
# 		ENDLAG: 3+
# Startup 2: 1-3 [3] -> Active 2
# Active 2: 4-5 [2] -> Recovery 2
# 	Jab 2 Sour: 4-6
# 	Jab 2 Sweet: 4-5
# Recovery 2: 6-26 [21] ->
#
# ====Ftilt====
# Startup 1: 1-12 [12] -> Active 1
# Active 1: 13-15 [3] -> Recovery 1
# 	Pull: 13-15
# Recovery 1: 16-37 [22] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 21-25
# 		ENDLAG: 5-9
# 	[CANCEL: AttackPressed>
# 		IASA: 21-30
# 		ENDLAG: 5-14
# Startup 2: 1-5 [5] -> Active 2
# Active 2: 6-10 [5] -> Recovery 2
# 	Sour: 6-10
# 	Sweet: 7-10
# Recovery 2: 11-44 [34] ->
#
# ====Utilt====
# Startup: 1-8 [8] -> Active
# Active: 9-17 [9] -> Recovery
# 	Early: 9-11
# 	Mid: 12-14
# 	Late: 15-17
# Recovery: 18-37 [20] ->
#
# ====Dtilt====
# Startup: 1-13 [13] -> Active
# Active: 14-16 [3] -> Recovery
# 	Sweet: 14-16
# 	Sour: 14-16
# Recovery: 17-36 [20] ->
#
# ====Dattack====
# Startup: 1-15 [15] -> Active
# 	[CANCEL: StateInt0>
# 		IASA: 16+
# 		ENDLAG: 15+
# Active: 16-18 [3] -> Recovery
# 	Early: 16-18
# 	Late: 18
# Recovery: 19-40 [22] ->
# Active (Lava): 1-3 [3] -> Recovery
# 	Early: 1-3
# 	Late: 3
# 	Lava: 2-3
#
# ====Fstrong====
# Pre-Charge: 1-20 [20] -> Charge
# Post-Charge: 21-27 [7] -> Active
# Active: 28-33 [6] -> Recovery
# 	Sour Early: 28-29
# 	Sweet Early: 28-29
# 	Sour Late: 30-33
# 	Sweet Late: 30-33
# Recovery: 34-67 [34] ->
#
# ====Ustrong====
# Pre-Charge: 1-9 [9] -> Charge
# Post-Charge: 10-14 [5] -> Active
# Active: 15-19 [5] -> Recovery
# 	Sour: 15-17
# 	Sweet: 15-18
# 	Late: 18-19
# Recovery: 20-49 [30] ->
#
# ====Dstrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-16 [6] -> Active
# Active: 17-28 [12] -> Recovery
# 	Sour Early: 17-22
# 	Sweet Early: 17-22
# 	Sour Late: 23-28
# 	Sweet Late: 23-28
# Recovery: 29-60 [32] ->
#
# ====Nair====
# Startup: 1-7 [7] -> Active 1
# Active 1: 8-9 [2] -> Between 1
# 	Hit 1: 8-9
# Between 1: 10-13 [4] -> Active 2
# Active 2: 14-15 [2] -> Between 2
# 	Hit 2: 14-15
# Between 2: 16-17 [2] -> Active 3
# Active 3: 18-21 [4] -> Recovery
# 	Hit 3: 18-21
# Recovery: 22-43 [22] ->
#
# ====Fair====
# Startup: 1-10 [10] -> Active
# Active: 11-14 [4] -> Recovery
# 	Sweet: 11-12
# 	Sour: 13-14
# Recovery: 15-38 [24] ->
#
# ====Bair====
# Startup: 1-8 [8] -> Active
# Active: 9-12 [4] -> Recovery
# 	Sweet: 9-10
# 	Sour: 11-12
# Recovery: 13-38 [26] ->
#
# ====Dair====
# Startup: 1-15 [15] -> Active
# Active: 16-19 [4] -> Recovery
# 	Stomp: 16-19
# Recovery: 20-39 [20] ->
#
# ====Uair====
# Startup: 1-10 [10] -> Active
# Active: 11-16 [6] -> Recovery
# 	Sour: 11-16
# 	Sweet Early: 11-12
# 	Sweet Late: 13-16
# Recovery: 17-39 [23] ->
#
# ====Nspecial====
# Pre-Charge: 1-14 [14] -> Charging
# Post-Charge: 15-16 [2] -> Active Ground
# 	[CANCEL: Aerial>
# 		IASA: 17+
# 		ENDLAG: 2+
# Active Ground: 17-22 [6] -> Recovery
# 	Launch: 21-26
# Active Air: 1-6 [6] -> Recovery
# 	Launch: 1-6
# Recovery: 7-29 [23] ->
#
# ====Fspecial====
# Startup: 1-16 [16] -> Active
# Active: 17-37 [21] -> Recovery Start
# 	[CANCEL: OnGrab>
# 		IASA: 16+
# 		ENDLAG: -1+
# 	None: 17-37
# Recovery Start: 38-47 [10] -> Grounded Recovery
# 	[CANCEL: Aerial>
# 		IASA: 48+
# 		ENDLAG: 10+
# Grounded Recovery: 48-75 [28] ->
# 	[CANCEL: Aerial>
# 		IASA: 47+
# 		ENDLAG: -1+
# Looping Special Fall: 1-16 [16] -> Looping Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 16+
# 		ENDLAG: -1+
# Special Land: 1-30 [30] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# Grabbed Opponent: 1-30 [30] -> Slam Active
# Slam Active: 31-31 [1] -> Slam Recovery
# Slam Recovery: 32-47 [16] ->
# 	[CANCEL: Aerial>
# 		IASA: 32+
# 		ENDLAG: 0+
# Slam Recovery (Air): 1-10 [10] ->
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
#
# ====Uspecial====
# Startup: 1-23 [23] -> Rising Active
# Rising Active: 24-32 [9] -> Between Hits
# 	Rising Front: 24-32
# 	Rising Back: 24-32
# Between Hits: 33-46 [14] -> Looping Falling Active
# Looping Falling Active: 47-58 [12] -> Looping Falling Active
# 	[CANCEL: Grounded>
# 		IASA: 58+
# 		ENDLAG: -1+
# 	Falling: 59-70
# Landing Active: 1-4 [4] -> Landing Recovery
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# 	Landing: 1-4
# Landing Recovery: 5-36 [32] ->
# 	[CANCEL: Aerial>
# 		IASA: 5+
# 		ENDLAG: 0+
#
# ====Dspecial====
# Startup: 1-8 [8] -> level 0 active
# 	[CANCEL: CharacterSpecific3>
# 		IASA: 9+
# 		ENDLAG: 8+
# 	[CANCEL: CharacterSpecific2>
# 		IASA: 9+
# 		ENDLAG: 8+
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 9+
# 		ENDLAG: 8+
# level 0 active: 9-11 [3] -> level 0 recovery
# 	Flub: 9-11
# level 0 recovery: 12-33 [22] ->
# level 1 active: 1-4 [4] -> level 1 recovery
# level 1 recovery: 5-19 [15] ->
# level 2 active: 1-4 [4] -> level 2 recovery
# level 2 recovery: 5-19 [15] ->
# level 3 active: 1-4 [4] -> level 3 recovery
# level 3 recovery: 5-19 [15] ->
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active 1
# Active 1: 11-13 [3] -> Active 2
# 	Pummel: 11-13
# Active 2: 14-16 [3] -> Active 3
# 	Pummel: 14-16
# Active 3: 17-19 [3] -> Recovery
# 	Pummel: 17-19
# Recovery: 20-39 [20] ->
#
# ====Fthrow====
# Startup: 1-10 [10] -> Release
# Release: 11-11 [1] -> Charging Up
# Charging Up: 12-51 [40] -> Swing Start
# Swing Start: 52-54 [3] -> Active
# Active: 55-59 [5] -> Recovery
# 	Sour: 55-64
# 	Sweet: 55-64
# Recovery: 60-86 [27] ->
#
# ====Bthrow====
# Startup: 1-19 [19] -> Active
# Active: 20-20 [1] -> Recovery
# Recovery: 21-47 [27] ->
#
# ====Uthrow====
# Startup: 1-13 [13] -> Active
# Active: 14-15 [2] -> Recovery
# 	Uthrow: 14-15
# Recovery: 16-45 [30] ->
#
# ====Dthrow====
# Startup: 1-21 [21] -> Active
# Active: 22-22 [1] -> Recovery
# 	[CANCEL: StateInt0>
# 		IASA: 23+
# 		ENDLAG: 1+
# Recovery: 23-45 [23] ->
# Lava Active: 1-1 [1] -> Recovery
# 	Lava Hit: 1
#
# ====LedgeAttack====
# Startup: 1-21 [21] -> Active
# Active: 22-25 [4] -> Recovery
# 	Lattack: 22-25
# Recovery: 26-55 [30] ->
#
# ====LedgeSpecial====
# Startup: 1-30 [30] -> Active
# Active: 31-42 [12] -> Recovery
# 	Lspecial: 31-42
# Recovery: 43-72 [30] ->
#
# ...
# Between 2: 16-17 [2] -> Active 3
# Active 3: 18-19 [2] -> Recovery
# 	Final Hit: 18-19
# Recovery: 20-45 [26] ->
#
# ====Utilt====
# Startup: 1-14 [14] -> Active
# Active: 15-18 [4] -> Recovery
# 	Top: 15
# 	Spike: 16-18
# 	Sour: 15-18
# Recovery: 19-39 [21] ->
#
# ====Dtilt====
# Startup: 1-6 [6] -> Active
# Active: 7-9 [3] -> Recovery
# 	Sour: 7-9
# 	Sweet: 7-9
# Recovery: 10-32 [23] ->
#
# ====Dattack====
# Startup: 1-6 [6] -> Active
# Active: 7-18 [12] -> Recovery
# 	Early: 7-10
# 	Late: 11-18
# Recovery: 19-38 [20] ->
# 	[CANCEL: Aerial>
# 		IASA: 19+
# 		ENDLAG: 0+
# Recovery (Air): 1-20 [20] ->
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
# 	[CANCEL: JumpPressed>
# 		IASA: 11+
# 		ENDLAG: 10+
#
# ====Fstrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-15 [5] -> Active
# Active: 16-19 [4] -> Recovery
# 	Sourspot: 16-19
# 	Sweetspot: 16-17
# Recovery: 20-54 [35] ->
# 	[CANCEL: Grounded>
# 		IASA: 20+
# 		ENDLAG: 0+
# Landing: 1-35 [35] ->
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
#
# ====Ustrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-16 [6] -> Active
# Active: 17-20 [4] -> Recovery
# 	Sweetspot: 17-18
# 	Sourspot: 17-20
# Recovery: 21-52 [32] ->
# 	[CANCEL: Grounded>
# 		IASA: 21+
# 		ENDLAG: 0+
# Landing: 1-32 [32] ->
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
#
# ====Dstrong====
# Pre-Charge: 1-7 [7] -> Charge
# Post-Charge: 8-11 [4] -> Active
# Active: 12-35 [24] -> Recovery
# 	[CANCEL: Grounded>
# 		IASA: 12+
# 		ENDLAG: 0+
# 	[CANCEL: OnAnyHit>
# 		IASA: 12+
# 		ENDLAG: 0+
# 	Dstrong: 12-35
# Recovery: 36-40 [5] ->
# 	[CANCEL: Grounded>
# 		IASA: 36+
# 		ENDLAG: 0+
# 	[CANCEL: OnAnyHit>
# 		IASA: 36+
# 		ENDLAG: 0+
# Landing: 1-24 [24] ->
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# Bounce: 1-18 [18] ->
#
# ====Nair====
# Startup: 1-4 [4] -> Active 1
# Active 1: 5-7 [3] -> Between Hits
# 	Hit 1: 5-7
# Between Hits: 8-15 [8] -> Active 2
# Active 2: 16-27 [12] -> Recovery
# 	Hit 2 Early: 16-18
# 	Hit 2 Late: 19-27
# Recovery: 28-45 [18] ->
#
# ====Fair====
# Startup: 1-8 [8] -> Active
# Active: 9-12 [4] -> Recovery
# 	Base: 9-12
# 	Tipper: 9-12
# Recovery: 13-35 [23] ->
#
# ====Bair====
# Startup: 1-5 [5] -> Active
# Active: 6-15 [10] -> Recovery
# 	Sweetspot: 6-8
# 	Sourspot: 6-15
# Recovery: 16-37 [22] ->
#
# ====Dair====
# Startup: 1-9 [9] -> Active 1
# Active 1: 10-13 [4] -> Active 2
# 	Feet: 10-13
# Active 2: 14-15 [2] -> Recovery
# 	Wing Spike: 14-15
# Recovery: 16-31 [16] ->
#
# ====Uair====
# Startup: 1-8 [8] -> Active
# Active: 9-14 [6] -> Recovery
# 	Early: 9-11
# 	Late: 12-14
# Recovery: 15-42 [28] ->
#
# ====Nspecial====
# Startup: 1-7 [7] -> Active Loop 1
# Active Loop 1: 8-11 [4] -> Active Loop 2
# 	Multihit: 8-12
# 	Multihit Bottom: 8-12
# Active Loop 2: 12-15 [4] -> Active Loop 3
# 	Multihit: 12-16
# 	Multihit Bottom: 12-16
# Active Loop 3: 16-19 [4] -> Active Loop 1
# 	Multihit: 16-20
# 	Multihit Bottom: 16-20
# Between Hits: 1-1 [1] -> Final Active
# Final Active: 2-4 [3] -> Recovery
# 	Final Hit: 2-4
# Recovery: 5-22 [18] -> Grounded Recovery
# Grounded Recovery: 23-40 [18] ->
# 	[CANCEL: Aerial>
# 		IASA: 23-23
# 		ENDLAG: 0-0
# Special Fall: 1-12 [12] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 13+
# 		ENDLAG: 0+
# Special Land: 1-24 [24] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# 	[CANCEL: Parried>
# 		IASA: 0+
# 		ENDLAG: -1+
#
# ====Fspecial====
# Startup: 1-7 [7] -> Active
# Active: 8-8 [1] -> Recovery
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 8-8
# 		ENDLAG: 0-0
# Recovery: 9-22 [14] ->
# Cooldown Recovery: 1-8 [8] ->
#
# ====Uspecial====
# Startup: 1-6 [6] -> Active 1
# Active 1: 7-7 [1] -> Active 2
# 	Sweetspot: 7
# Active 2: 8-15 [8] -> Recovery
# 	Sour Early: 8-11
# 	Sour Late: 12-15
# Recovery: 16-40 [25] -> Special Fall
# Special Fall: 41-52 [12] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 52+
# 		ENDLAG: -1+
# Special Land: 1-30 [30] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# 	[CANCEL: Parried>
# 		IASA: 0+
# 		ENDLAG: -1+
#
# ====Dspecial====
# Startup: 1-18 [18] -> Active
# Active: 19-36 [18] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 19+
# 		ENDLAG: 0+
# 	[CANCEL: OnAnyHit>
# 		IASA: 19+
# 		ENDLAG: 0+
# 	Hit Object: 19-36
# Recovery: 37-69 [33] ->
# 	[CANCEL: Aerial>
# 		IASA: 37+
# 		ENDLAG: 0+
# Recovery (Air): 1-15 [15] ->
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
# Throw: 1-20 [20] -> Throw Recovery
# Throw Recovery: 21-26 [6] ->
# 	[CANCEL: Aerial>
# 		IASA: 22+
# 		ENDLAG: 1+
# Throw Recovery (Air): 1-6 [6] ->
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
# Shield Bounce: 1-30 [30] ->
# 	[CANCEL: Grounded>
# 		IASA: 2+
# 		ENDLAG: 1+
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active 1
# Active 1: 11-14 [4] -> Active 2
# 	Spummel: 11-14
# Active 2: 15-18 [4] -> Active 3
# 	Spummel: 15-18
# Active 3: 19-22 [4] -> Recovery
# 	Spummel: 19-22
# Recovery: 23-37 [15] ->
#
# ====Fthrow====
# Startup: 1-17 [17] -> Active
# Active: 18-19 [2] -> Recovery
# 	Fthrow: 18-19
# Recovery: 20-40 [21] ->
#
# ====Bthrow====
# Startup: 1-19 [19] -> Active
# Active: 20-20 [1] -> Recovery
# 	Bthrow: 20
# 	Spike: 20
# Recovery: 21-43 [23] ->
#
# ====Uthrow====
# Startup: 1-13 [13] -> Active
# Active: 14-16 [3] -> Recovery
# 	Uthrow: 14-16
# Recovery: 17-46 [30] ->
#
# ====Dthrow====
# Startup: 1-30 [30] -> Active
# Active: 31-31 [1] -> Recovery
# Recovery: 32-42 [11] ->
# 	[CANCEL: Grounded>
# 		IASA: 32+
# 		ENDLAG: 0+
#
# ====LedgeAttack====
# Startup: 1-21 [21] -> Active 1
# Active 1: 22-23 [2] -> Between Hits
# 	Lattack: 22-23
# Between Hits: 24-27 [4] -> Active 2
# Active 2: 28-29 [2] -> Recovery
# 	Lattack: 28-29
# Recovery: 30-55 [26] ->
#
# ====LedgeSpecial====
# Startup: 1-20 [20] -> Rising
# Rising: 21-30 [10] -> Stalled
# Stalled: 31-35 [5] -> Falling Active
# Falling Active: 36-45 [10] -> Landing Active
# 	Dive KB: 36-44
# Landing Active: 46-48 [3] -> Recovery
# 	Landing KB: 46-48
# Recovery: 49-81 [33] ->
#
# ====GetupAttack====
# Startup: 1-16 [16] -> Active 1
# Active 1: 17-18 [2] -> Between Hits
# 	Gattack: 17-18
# Between Hits: 19-21 [3] -> Active 2
# Active 2: 22-23 [2] -> Recovery
# 	Gattack: 22-23
# Recovery: 24-50 [27] ->
#
# ====GetupSpecial====
# Startup: 1-23 [23] -> Active 1
# Active 1: 24-27 [4] -> Active 2
# 	Multihit: 24-27
# Active 2: 28-31 [4] -> Active Final 1
# 	Multihit: 28-31
# Active Final 1: 32-35 [4] -> Recovery 1
# 	[CANCEL: SpecialDown>
# 		IASA: 32-32
# 		ENDLAG: 0-0
# 	Final Hit: 32-35
# Recovery 1: 36-67 [32] ->
# Active 3: 1-4 [4] -> Active 4
# 	Multihit: 1-4
# Active 4: 5-8 [4] -> Active 5
# 	Multihit: 5-8
# Active 5: 9-12 [4] -> Active 6
# 	Multihit: 9-12
# Active 6: 13-16 [4] -> Active Final 2
# 	Multihit: 13-16
# Active Final 2: 17-20 [4] -> Recovery 2
# 	Final Hit: 17-20
# Recovery 2: 21-58 [38] ->
#
# ====DspecialAir====
# Startup: 1-18 [18] -> Active
# Active: 19-36 [18] -> Recovery
# 	[CANCEL: Grounded>
# 		IASA: 19+
# 		ENDLAG: 0+
# 	[CANCEL: OnGrab>
# 		IASA: 19+
# 		ENDLAG: 0+
# 	[CANCEL: OnAnyHit>
# 		IASA: 19+
# 		ENDLAG: 0+
# 	Hit Object: 19-36
# Recovery: 37-51 [15] ->
# 	[CANCEL: Grounded>
# 		IASA: 37+
# 		ENDLAG: 0+
# Landing Active: 1-1 [1] -> Landing Recovery
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# 	Landing: 1
# Landing Recovery: 2-26 [25] ->
# 	[CANCEL: Aerial>
# 		IASA: 2+
# 		ENDLAG: 0+
# Whiff Landing: 1-10 [10] ->
# 	[CANCEL: Aerial>
# 		IASA: 1+
# 		ENDLAG: 0+
# Throw: 1-20 [20] -> Throw Recovery
# Throw Recovery: 21-26 [6] ->
# Shield Bounce: 1-30 [30] ->
# 	[CANCEL: Grounded>
# 		IASA: 1+
# 		ENDLAG: 0+
#
# ====Intro====
# Loop: 1-45 [45] -> Spin
# Spin: 46-80 [35] -> Landing
# Landing: 81-120 [40] ->
#
# ====Taunt1====
# Startup: 1-39 [39] -> Loop
# Loop: 40-68 [29] -> Loop
# 	[CANCEL: TauntReleased>
# 		IASA: 69+
# 		ENDLAG: 0+
# Recovery: 1-20 [20] ->
#
# ====Taunt2====
# Combing Hair: 1-62 [62] -> Finger Guns
# Finger Guns: 63-96 [34] -> Recovery
# Recovery: 97-140 [44] ->
#
# ====Slipstream====
# Intro: 1-30 [30] -> Active
# Active: 31-570 [540] -> Outro
# Outro: 571-600 [30] ->
# Cooldown: 1-300 [300] ->
#
# ====SlipstreamSplitter====
# Active: 1-90 [90] ->
# 	Proj KB: 1-300
#
# ====SlipstreamTornado====
# Active: 1-300 [300] ->
# 	Proj KB: 1-300
#
# ====WindPlatform====
# Rising: 1-30 [30] -> Idle
# Idle: 31-130 [100] -> Destroy
# Destroy: 131-160 [30] ->
#
#
# = Zetterburn =
#
# ====Jab====
# Startup 1: 1-4 [4] -> Active 1
# Active 1: 5-6 [2] -> Recovery 1
# 	Jab 1: 5-6
# Recovery 1: 7-20 [14] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 11+
# 		ENDLAG: 4+
# Startup 2: 1-3 [3] -> Active 2
# Active 2: 4-5 [2] -> Recovery 2
# 	Jab 2: 4-5
# Recovery 2: 6-21 [16] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 8+
# 		ENDLAG: 2+
# Startup 3: 1-5 [5] -> Active 3
# Active 3: 6-7 [2] -> Recovery 3
# 	Jab Final: 6-7
# Recovery 3: 8-24 [17] ->
#
# ====Ftilt====
# Startup: 1-8 [8] -> Active 1
# 	[CANCEL: UpDown>
# 		IASA: 9+
# 		ENDLAG: 8+
# 	[CANCEL: DownDown>
# 		IASA: 9+
# 		ENDLAG: 8+
# Active 1: 9-9 [1] -> Active 2
# 	Linking Hit: 9
# Active 2: 10-12 [3] -> Recovery
# 	Final Hit: 10-12
# Recovery: 13-30 [18] ->
# Active 1 Up: 1-1 [1] -> Active 2 Up
# 	Linking Hit: 1
# Active 2 Up: 2-4 [3] -> Recovery Up
# 	Final Hit: 2-4
# Recovery Up: 5-22 [18] ->
# Active 1 Down: 1-1 [1] -> Active 2 Down
# 	Linking Hit: 1
# Active 2 Down: 2-4 [3] -> Recovery Down
# 	Final Hit: 2-4
# Recovery Down: 5-22 [18] ->
#
# ====Utilt====
# Startup: 1-8 [8] -> Active
# Active: 9-14 [6] -> Recovery
# 	Sour: 9-14
# 	Sweet: 9-14
# Recovery: 15-30 [16] ->
#
# ====Dtilt====
# Startup: 1-5 [5] -> Active
# Active: 6-8 [3] -> Recovery
# 	Sourspot: 6-8
# 	Sweetspot: 6-8
# Recovery: 9-24 [16] ->
#
# ====Dattack====
# Startup: 1-6 [6] -> Boost
# Boost: 7-9 [3] -> Active
# Active: 10-13 [4] -> Recovery
# 	Sweetspot: 10
# 	Sourspot: 11-13
# Recovery: 14-31 [18] ->
#
# ====Fstrong====
# Pre-Charge: 1-10 [10] -> Charge
# Post-Charge: 11-16 [6] -> Active 1
# Active 1: 17-19 [3] -> Active 2
# 	Linking Hit: 17-19
# Active 2: 20-21 [2] -> Recovery
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 21+
# 		ENDLAG: 1+
# 	Final Hit: 20-21
# Recovery: 22-51 [30] ->
# Consume Active: 1-3 [3] -> Consume Recovery
# 	Consume: 1-3
# Consume Recovery: 4-31 [28] ->
#
# ====Ustrong====
# Pre-Charge: 1-6 [6] -> Charge
# Post-Charge: 7-9 [3] -> Active
# Active: 10-12 [3] -> Recovery
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 13+
# 		ENDLAG: 3+
# 	Ustrong KB: 10-14
# Recovery: 13-46 [34] ->
# Consume Active: 1-3 [3] -> Consume Recovery
# 	Consume: 1-3
# Consume Recovery: 4-35 [32] ->
#
# ====Dstrong====
# Pre-Charge: 1-4 [4] -> Charge
# Post-Charge: 5-6 [2] -> Active 1
# Active 1: 7-8 [2] -> Between Hits
# 	Hit 1 Cross: 7-8
# Between Hits: 9-15 [7] -> Active 2
# Active 2: 16-17 [2] -> Recovery
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 17+
# 		ENDLAG: 1+
# 	Hit 2: 16-17
# Recovery: 18-47 [30] ->
# Consume Active: 1-3 [3] -> Consume Recovery
# 	Consume: 1-3
# Consume Recovery: 4-31 [28] ->
#
# ====Nair====
# Startup: 1-5 [5] -> Active 1
# Active 1: 6-7 [2] -> Between 1
# 	Multihit: 6-7
# 	Multihit Ground: 6-7
# Between 1: 8-9 [2] -> Active 2
# Active 2: 10-11 [2] -> Between 2
# 	Multihit: 10-11
# 	Multihit Ground: 10-11
# Between 2: 12-13 [2] -> Active 3
# Active 3: 14-15 [2] -> Between 3
# 	Multihit: 14-15
# 	Multihit Ground: 14-15
# Between 3: 16-17 [2] -> Active Final
# Active Final: 18-20 [3] -> Recovery
# 	Final Hit: 18-20
# Recovery: 21-32 [12] ->
#
# ====Fair====
# Startup: 1-10 [10] -> Active
# Active: 11-13 [3] -> Recovery
# 	Sweetspot: 12-13
# 	Sourspot: 11-13
# Recovery: 14-31 [18] ->
#
# ====Bair====
# Startup: 1-9 [9] -> Active
# Active: 10-12 [3] -> Recovery
# 	Sourspot: 10-12
# 	Tipper: 10-12
# Recovery: 13-24 [12] ->
#
# ====Dair====
# Startup: 1-14 [14] -> Active
# Active: 15-19 [5] -> Recovery
# 	Sourspot: 15-19
# 	Sweetspot: 15
# Recovery: 20-41 [22] ->
#
# ====Uair====
# Startup: 1-8 [8] -> Active
# Active: 9-12 [4] -> Recovery
# 	Sweetspot: 9
# 	Super Sour: 9-12
# 	Sourspot: 9-12
# Recovery: 13-28 [16] ->
#
# ====Nspecial====
# Startup: 1-1 [1] -> Charging
# Charged Active: 2-4 [3] -> Charged Recovery
# 	Charged: 2-4
# Charged Recovery: 5-28 [24] ->
# Uncharged Active: 1-3 [3] -> Uncharged Recovery
# 	Uncharged: 1-3
# Uncharged Recovery: 4-23 [20] ->
#
# ====Fspecial====
# Startup: 1-15 [15] -> Active
# Active: 16-16 [1] -> Recovery
# 	Mane KB: 16
# Recovery: 17-35 [19] ->
#
# ====Uspecial====
# Startup: 1-16 [16] -> Active 1
# Active 1: 17-18 [2] -> Active 2
# 	Multihit: 17-18
# Active 2: 19-20 [2] -> Active 3
# 	Multihit: 19-20
# Active 3: 21-22 [2] -> Active 4
# 	Multihit: 21-22
# Active 4: 23-24 [2] -> Active 5
# 	Multihit: 23-24
# Active 5: 25-26 [2] -> Active 6
# 	Multihit: 25-26
# Active 6: 27-28 [2] -> Active 7
# 	Multihit: 27-28
# Active 7: 29-30 [2] -> Travel Active
# 	Multihit: 29-30
# Travel Active: 31-54 [24] -> Recovery
# 	Final Hit: 31-54
# Recovery: 55-79 [25] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 56+
# 		ENDLAG: 1+
# Special Fall: 80-97 [18] -> Special Fall
# 	[CANCEL: Grounded>
# 		IASA: 97+
# 		ENDLAG: -1+
# Special Land: 1-15 [15] ->
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# 	[CANCEL: Parried>
# 		IASA: 0+
# 		ENDLAG: -1+
# Special Bounce: 1-24 [24] ->
# 	[CANCEL: Grounded>
# 		IASA: 3+
# 		ENDLAG: 2+
#
# ====Dspecial====
# Startup: 1-22 [22] -> Active
# 	[CANCEL: Aerial>
# 		IASA: 0+
# 		ENDLAG: -1+
# Active: 23-25 [3] -> Recovery
# 	Slam KB: 23-25
# Recovery: 26-57 [32] ->
#
# ====Grab====
# Startup: 1-6 [6] -> Active
# Active: 7-8 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 6+
# 		ENDLAG: -1+
# 	None: 7-8
# Recovery: 9-31 [23] ->
# Hold: 1-60 [60] -> Release
# 	[CANCEL: OnThrow>
# 		IASA: 0+
# 		ENDLAG: -1+
# Release: 61-92 [32] ->
#
# ====DashGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-38 [27] ->
#
# ====PivotGrab====
# Startup: 1-9 [9] -> Active
# Active: 10-11 [2] -> Recovery
# 	[CANCEL: OnGrab>
# 		IASA: 9+
# 		ENDLAG: -1+
# 	None: 10-11
# Recovery: 12-41 [30] ->
#
# ====Pummel====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====PummelSpecial====
# Startup: 1-10 [10] -> Active
# Active: 11-11 [1] -> Recovery
# 	Pummel: 11
# Recovery: 12-31 [20] ->
#
# ====Fthrow====
# Startup: 1-31 [31] -> Active
# Active: 32-33 [2] -> Recovery
# 	[CANCEL: CharacterSpecific1>
# 		IASA: 33-33
# 		ENDLAG: 1-1
# 	Normal: 32-33
# Recovery: 34-63 [30] ->
# Consume Active: 1-1 [1] -> Recovery
# 	Empowered: 1
#
# ====Bthrow====
# Startup: 1-21 [21] -> Active
# Active: 22-22 [1] -> Recovery
# Recovery: 23-49 [27] ->
#
# ====Uthrow====
# Startup: 1-10 [10] -> Active
# Active: 11-13 [3] -> Recovery
# 	Uthrow: 11-13
# Recovery: 14-41 [28] ->
#
# ====Dthrow====
# Startup: 1-11 [11] -> Active
# Active: 12-12 [1] -> Recovery
# 	Dthrow: 12-14
# Recovery: 13-35 [23] ->
#
# ====LedgeAttack====
# Startup: 1-24 [24] -> Active
# Active: 25-27 [3] -> Recovery
# 	Lattack: 25-27
# Recovery: 28-55 [28] ->
#
# ====LedgeSpecial====
# Startup: 1-30 [30] -> Active
# Active: 31-40 [10] -> Recovery
# 	Lspecial: 31-40
# Recovery: 41-76 [36] ->
# Bounce: 1-12 [12] ->
#
# ====GetupAttack====
# Startup: 1-15 [15] -> Active
# Active: 16-22 [7] -> Recovery
# 	Gattack: 16-22
# Recovery: 23-50 [28] ->
#
# ====GetupSpecial====
# Startup: 1-36 [36] -> Active
# Active: 37-40 [4] -> Recovery
# 	Gspecial: 37-40
# Recovery: 41-70 [30] ->
#
# ====DspecialAir====
# Startup: 1-22 [22] -> Active Loop
# 	[CANCEL: StateInt0>
# 		IASA: 9-9
# 		ENDLAG: 8-8
# Active Loop: 23-29 [7] -> Active Loop
# 	[CANCEL: Grounded>
# 		IASA: 29+
# 		ENDLAG: -1+
# 	Dive KB: 30-36
# 	Dive KB Ground: 30-36
# Cancel: 1-28 [28] -> Cancel Fall
# 	[CANCEL: Grounded>
# 		IASA: 0+
# 		ENDLAG: -1+
# Cancel Fall: 29-35 [7] -> Cancel Fall
# 	[CANCEL: Grounded>
# 		IASA: 35+
# 		ENDLAG: -1+
# Cancel Roll: 1-8 [8] -> Cancel Recovery Grounded
# Cancel Recovery Grounded: 9-24 [16] ->
# 	[CANCEL: Aerial>
# 		IASA: 8+
# 		ENDLAG: -1+
# Cancel Recovery Aerial: 1-8 [8] ->
# 	[CANCEL: Grounded>
# 		IASA: 0+
# 		ENDLAG: -1+
#
# ====Intro====
# Dive: 1-18 [18] -> Land
# Land: 19-40 [22] -> Roar
# Roar: 41-120 [80] ->
#
# ====Taunt1====
# Full Taunt: 1-68 [68] ->
#
# ====Taunt2====
# Full Taunt: 1-130 [130] ->
#
# ====Fireball====
# Active: 1-30 [30] -> Destroy
# 	Fireball KB: 1-30
# Destroy: 31-40 [10] ->
#
# ====FlamePuddle====
# Active: 1-300 [300] -> Destroy
# 	None: 2-300
# Destroy: 301-312 [12] ->
#
# ====MovingFlamePuddle====
# Create: 1-10 [10] -> Active
# 	None: 2-10
# Active: 11-40 [30] -> Destroy
# 	None: 11-40
# Destroy: 41-65 [25] ->

# %% [markdown]
# A guide to interpreting the results above:
#
# = Character =
# ==== MoveName ====
# "Window Name": "Frame Duration Start" - "Frame Duration End" ["Window Length"] -> "Next Window"
#     "Hit 1": "Hit Duration Start" - "Hit Duration End"
#     "Hit 2": "Hit Duration Start" - "Hit Duration End"
#     [CANCEL: Trigger>
#         IASA: IASA number. If it's +, there is no limit when the action can be cancelled. If there is a duration, it will list the last possible frame that can be cancelled.
#         ENDLAG: Endlag number. See above.
#
# For example:
#
# ====Ftilt====
# Startup 1: 1-12 [12] -> Active 1
# Active 1: 13-15 [3] -> Recovery 1
# 	Pull: 13-15
# Recovery 1: 16-37 [22] ->
# 	[CANCEL: AttackPressed>
# 		IASA: 21-25
# 		ENDLAG: 5-9
# 	[CANCEL: AttackPressed>
# 		IASA: 21-30
# 		ENDLAG: 5-14
# Startup 2: 1-5 [5] -> Active 2
# Active 2: 6-10 [5] -> Recovery 2
# 	Sour: 6-10
# 	Sweet: 7-10
# Recovery 2: 11-44 [34] ->
#
# From this, we can get 12 startup, 13-15 active frames, an endlag of 22 and an IASA of 37 + 1 = 38. We can also get the endlag cancels (5-9) on whiff, and (5-14) on shield, with an IASA of 21-25 and 21-30 respectively.
# WE also get the second hit, with 5 startup, different active frames depending on hit, and an endlag of 34 with an IASA of 45.

# %%
# Run this cell to update the tumble %s sheet.

def relay(chare, x):
    if 'KBs' not in char_data[chare][x].keys():
        return
    for y1 in char_data[chare][x]['KBs'].keys():
        s = chare + '\t' + x + '\t' + char_data[chare][x]['KBs'][y1]['Hit/Hitbox'] + '\t' + str(char_data[chare][x]['KBs'][y1]['damage']) + '\t' + str(char_data[chare][x]['KBs'][y1]['base_kb']) + '\t' + str(char_data[chare][x]['KBs'][y1]['kb_scale']) + '\t'
        if(char_data[chare][x]['KBs'][y1]['weight_independent']):
            s += 'True'
        s += '\t'
        if(char_data[chare][x]['KBs'][y1]['force_tumble']):
            s += 'True'
        # s += '\t'
        print(s)        
    if (char_data[chare][x]['Throws']):
        y1 = char_data[chare][x]['Throws'][0]
        # print(y1)
        s = chare + '\t' + x + '\tThrow\t' + str(y1['damage']) + '\t' + str(y1['base_kb']) + '\t' + str(y1['kb_scale']) + '\t'
        s += 'True'
        s += '\t'
        if(y1['force_tumble']):
            s += 'True'
        # s += '\t'
        print(s)     

for k in char_data.keys():
    for i in forest_list:
        relay(k, i)

    for i in char_data[k].keys():
        if(i == 'Stats' or i in forest_list):
            continue
        if 'KBs' in char_data[k][i].keys():
            relay(k, i)
# Out:
# Clairen	Jab	Sour	3	6.0	0.2
# Clairen	Jab	Tipper	5	6.0	0.3
# Clairen	Ftilt	Sour	7	5.5	0.68
# Clairen	Ftilt	Tipper	9	5.0	0.95
# Clairen	Utilt	Sour	7	7.0	0.55
# Clairen	Utilt	Tipper	10	5.7	0.97
# Clairen	Dtilt	Sour	5	5.0	0.25
# Clairen	Dtilt	Tipper	9	7.0	0.35
# Clairen	Dattack	Sour	6	7.0	0.35
# Clairen	Dattack	Tipper	9	8.0	0.3
# Clairen	Fstrong	Sour	9	7.0	0.75
# Clairen	Fstrong	Tipper	13	7.5	1.13
# Clairen	Ustrong	Sour	8	8.0	0.85
# Clairen	Ustrong	Super Sour	7	8.0	0.5
# Clairen	Ustrong	Tipper	13	8.5	1.1
# Clairen	Dstrong	Sour 1	9	7.0	0.85
# Clairen	Dstrong	Tipper 1	13	8.0	1.2
# Clairen	Dstrong	Sour 2	9	7.0	0.85
# Clairen	Dstrong	Tipper 2	13	9.0	1.25
# Clairen	Nair	Multihit Sour	1	4.0	0.0	True
# Clairen	Nair	Multihit Tipper	2	6.0	0.4
# Clairen	Nair	Final Sour	3	7.0	0.45
# Clairen	Nair	Final Tipper	8	4.5	0.95
# Clairen	Fair	Sour 1	3	5.0	0.1	True
# Clairen	Fair	Sour 2	4	6.0	0.35
# Clairen	Fair	Super Sour 2	4	6.0	0.4
# Clairen	Fair	Tipper	7	4.0	0.86
# Clairen	Fair	Reverse Tipper	7	6.0	0.65
# Clairen	Bair	Sour	6	5.0	0.55
# Clairen	Bair	Sour Reverse	5	5.0	0.38
# Clairen	Bair	Tipper	9	6.2	1.0
# Clairen	Dair	Sour Early	7	6.0	0.45
# Clairen	Dair	Sour Late	5	5.0	0.35
# Clairen	Dair	Tipper Early	12	5.0	0.6
# Clairen	Dair	Tipper Late	12	5.0	0.6
# Clairen	Uair	Sour	6	7.0	0.45
# Clairen	Uair	Super Sour	5	6.0	0.3
# Clairen	Uair	Tipper	12	9.0	0.9
# Clairen	Uspecial	Multihit Early	1	13.0	0.0	True
# Clairen	Uspecial	Multihit Late	1	7.0	0.0	True
# Clairen	Uspecial	Final Sour	6	6.5	0.35
# Clairen	Uspecial	Final Tipper	9	8.0	0.5
# Clairen	Dspecial	Multihits	3	4.0	0.0	True
# Clairen	Dspecial	Final Hit	3	6.0	0.3
# Clairen	Dspecial	Projectile Killer KB	0	0.0	0.0
# Clairen	Pummel	Pummel	8	4.0	0.0	True
# Clairen	PummelSpecial	Pummel	8	4.0	0.0	True
# Clairen	Fthrow	Sour	3	7.5	0.2	True
# Clairen	Fthrow	Tipper	3	7.5	0.2	True
# Clairen	Bthrow	Sour	3	7.5	0.3	True
# Clairen	Bthrow	Tipper	3	7.5	0.3	True
# Clairen	Uthrow	Sour	5	11.0	0.45	True	True
# Clairen	Uthrow	Tipper	5	11.0	0.45	True	True
# Clairen	Dthrow	Sour	6	9.0	0.45	True	True
# Clairen	Dthrow	Tipper	6	9.0	0.45	True	True
# Clairen	LedgeAttack	Sour	5	8.0	0.3
# Clairen	LedgeAttack	Tipper	7	8.0	0.3
# Clairen	LedgeSpecial	Sour Ground	4	5.0	0.0	True	True
# Clairen	LedgeSpecial	Sour Air	4	7.0	0.0	True	True
# Clairen	GetupAttack	Sour	5	9.0	0.25
# Clairen	GetupAttack	Tipper	7	9.0	0.25
# Clairen	GetupSpecial	Sour	8	9.0	0.3
# Clairen	GetupSpecial	Tipper	10	9.0	0.45
# Clairen	FspecialX	Sour	8	8.0	0.8
# Clairen	FspecialX	Tipper	13	9.0	1.05
# Clairen	GroundPlasma	Lspecial	6	10.0	0.45
# Clairen	PlasmaField	Proj KB	0	0.0	0.0
# Clairen	QuickSlash	Sour 1	6	6.0	0.25
# Clairen	QuickSlash	Sour 2	6	6.0	0.4
# Clairen	QuickSlash	Sour 3	6	6.0	0.65
# Clairen	QuickSlash	Tipper 1	9	8.0	0.3
# Clairen	QuickSlash	Tipper 2	13	8.0	0.9
# Clairen	QuickSlash	Tipper 3	14	8.0	1.05
# Clairen	QuickSlash	Finisher	28	16.0	1.2
# Etalus	Jab	Hit 1	3	4.0	0.0	True
# Etalus	Jab	Hit 2	3	4.0	0.0	True
# Etalus	Jab	Hit 3 Sweet	6	6.5	0.55
# Etalus	Jab	Hit 3 Sour	4	5.0	0.25
# Etalus	Ftilt	Hit 1	2	4.0	0.0
# Etalus	Ftilt	Hit 2	2	4.0	0.0
# Etalus	Ftilt	Hit 3	6	5.75	0.45
# Etalus	Utilt	Sweet	10	8.0	0.9
# Etalus	Dtilt	Hit 1	5	4.0	0.1
# Etalus	Dtilt	Hit 2	6	6.0	0.6
# Etalus	Dattack	Early	5	6.0	0.45
# Etalus	Dattack	Late	4	4.5	0.4
# Etalus	Fstrong	Hit 1 Back	4	8.0	0.0	True
# Etalus	Fstrong	Hit 1 Front	4	6.0	0.0	True
# Etalus	Fstrong	Hit 2	10	7.0	1.1
# Etalus	Ustrong	Hit 1	3	13.0	0.0	True
# Etalus	Ustrong	Hit 2	12	7.0	1.15
# Etalus	Dstrong	Early	6	7.0	0.0	True
# Etalus	Dstrong	Sweet	12	7.0	1.15
# Etalus	Dstrong	Mid	10	4.5	1.05
# Etalus	Dstrong	Sour	6	4.0	0.7
# Etalus	Nair	Early	7	6.0	0.75
# Etalus	Nair	Late	5	4.0	0.4
# Etalus	Bair	Bair	9	4.0	0.77
# Etalus	Dair	Multihit	3	4.0	0.0
# Etalus	Dair	Final	7	6.0	0.5
# Etalus	Uair	Hit Object	5	5.0	0.0
# Etalus	Uair	Throw	11	5.0	0.5	True	True
# Etalus	Nspecial	Top	15	9.0	1.3
# Etalus	Nspecial	Base	15	10.0	1.3
# Etalus	Uspecial	Spike	8	3.0	0.6
# Etalus	Dspecial	Rising	4	9.0	0.0	True
# Etalus	Dspecial	Falling	12	8.0	1.1
# Etalus	Dspecial	Landing	8	8.0	0.85
# Etalus	Pummel	Pummel	8	4.0	0.0	True
# Etalus	PummelSpecial	Pummel	6	4.0	0.0	True
# Etalus	Fthrow	Roll	5	8.0	0.55	True	True
# Etalus	Bthrow	Throw	4	7.5	0.425	True	True
# Etalus	Uthrow	Uthrow	4	7.5	0.6	True	True
# Etalus	Dthrow	Slam	6	7.5	0.45	True	True
# Etalus	LedgeAttack	Lattack	4	8.0	0.3
# Etalus	LedgeSpecial	Slide	8	10.0	0.3
# Etalus	GetupAttack	Gattack	9	9.0	0.25
# Etalus	GetupSpecial	Gspecial	10	9.0	0.6
# Etalus	Fair2	Fair	11	5.5	1.0
# Etalus	IceHalo	Freeze	3	1.0	0.0
# Etalus	IceShard	Horizontal	3	6.0	0.3
# Etalus	IceShard	Vertical	3	6.0	0.3
# Etalus	Icicle	Fspecial	2	5.0	0.25
# Fleet	Jab	Jab 1	3	4.0	0.0	True
# Fleet	Jab	Jab 2	3	4.0	0.0	True
# Fleet	Jab	Jab Final	6	5.5	0.4
# Fleet	Jab	Jab Final Sour	5	5.5	0.4
# Fleet	Ftilt	Ftilt	7	3.5	0.85
# Fleet	Utilt	Multihit	2	4.0	0.0	True
# Fleet	Utilt	Final Hit	3	6.5	0.65
# Fleet	Dtilt	Sweet	6	7.0	0.4
# Fleet	Dtilt	Sour	6	6.0	0.4
# Fleet	Dattack	Multi	2	5.0	0.55	True
# Fleet	Dattack	Final	4	5.0	0.55
# Fleet	Dstrong	Early	12	7.5	1.15
# Fleet	Dstrong	Late	8	7.0	0.7
# Fleet	Nair	Early	9	4.25	0.85
# Fleet	Nair	Late	6	2.6	0.7
# Fleet	Fair	Multi	2	3.5	0.0	True
# Fleet	Fair	Final	3	5.0	0.4
# Fleet	Bair	Sweet	10	5.3	1.02
# Fleet	Bair	Sour	7	4.75	0.92
# Fleet	Bair	Reverse	5	5.0	0.4
# Fleet	Uair	Early	10	4.5	1.02
# Fleet	Uair	Late Sweet	7	4.5	0.88
# Fleet	Uair	Late Sour	5	4.5	0.55
# Fleet	Uspecial	Rising	4	12.0	0.3	True
# Fleet	Uspecial	Launch	12	6.5	0.9
# Fleet	Uspecial	Travel	9	6.5	0.85
# Fleet	Pummel	Pummel	8	4.0	0.0	True
# Fleet	PummelSpecial	Pummel	3	4.0	0.0	True
# Fleet	Fthrow	Fthrow	2	10.0	0.0	True	True
# Fleet	Bthrow	Throw	2	12.0	0.0	True	True
# Fleet	Uthrow	Throw	3	11.0	0.0	True	True
# Fleet	Dthrow	Shot	4	8.0	0.3	True	True
# Fleet	LedgeAttack	Lattack	6	8.0	0.3
# Fleet	GetupAttack	Gattack	6	9.0	0.25
# Fleet	PummelSpecial_OLD	Pummel	6	4.0	0.0	True
# Fleet	Arrow	Fstrong Early	11	8.0	0.9
# Fleet	Arrow	Fstrong Mid	8	6.0	0.75
# Fleet	Arrow	Fstrong Late	5	5.0	0.4
# Fleet	Arrow	Ustrong Early	14	7.0	1.15
# Fleet	Arrow	Ustrong Mid	10	7.0	0.9
# Fleet	Arrow	Ustrong Late	8	7.0	0.55
# Fleet	Arrow	Dair Early	11	5.5	0.55
# Fleet	Arrow	Dair Late	6	5.0	0.2
# Fleet	Arrow	Dspecial	7	8.0	0.4
# Fleet	Arrow	Uthrow	2	8.5	0.4	True	True
# Fleet	Arrow	Bthrow	2	8.0	0.4	True
# Fleet	Arrow	Bthrow Late	2	4.0	0.4	True
# Fleet	Arrow	Lspecial	7	8.0	0.4
# Fleet	Arrow	Ustrong Fall	4	6.0	0.0
# Fleet	HomingArrow	Multi	1	8.0	0.15	True
# Fleet	HomingArrow	Final	1	8.0	0.15
# Fleet	HomingArrow	Uthrow	2	8.5	0.3	True	True
# Fleet	Meat	Gspecial	4	8.0	0.3
# Fleet	StaminaTornado	Final	3	8.0	0.25
# Fleet	WindArrow	Arrow Early	5	7.0	0.35
# Fleet	WindArrow	Arrow Late	3	5.0	0.25
# Fleet	WindArrow	Tornado	1	6.0	0.0	True
# Forsburn	Jab	Jab 1	3	4.0	0.0	True
# Forsburn	Jab	Jab 2	3	6.0	0.0	True
# Forsburn	Jab	Jab 3	6	7.0	0.65
# Forsburn	Ftilt	Multihit	3	3.0	0.0
# Forsburn	Ftilt	Final	5	5.0	0.5
# Forsburn	Utilt	Multihit	2	6.0	0.0
# Forsburn	Utilt	Multihit High	2	3.0	0.0
# Forsburn	Utilt	Final	4	7.0	0.55
# Forsburn	Dtilt	Sweet	8	5.0	0.55
# Forsburn	Dtilt	Sour	6	4.8	0.55
# Forsburn	Dattack	Sweet	8	6.5	0.6
# Forsburn	Dattack	Sour	7	6.5	0.6
# Forsburn	Dattack	Top	5	5.5	0.35
# Forsburn	Fstrong	Cloak Outer	4	7.0	0.0	True
# Forsburn	Fstrong	Cloak Mid	4	7.0	0.0	True
# Forsburn	Fstrong	Cloak Inner	4	7.0	0.0	True
# Forsburn	Fstrong	Dagger	10	6.15	1.0
# Forsburn	Ustrong	Cloak Outer Low	4	7.5	0.05	True
# Forsburn	Ustrong	Cloak Outer High	4	6.0	0.0	True
# Forsburn	Ustrong	Cloak Inner	4	7.5	0.05	True
# Forsburn	Ustrong	Dagger	10	7.0	1.12
# Forsburn	Ustrong	Dagger Sour	8	6.0	1.0
# Forsburn	Dstrong	Dstrong	13	6.5	1.1
# Forsburn	Nair	Hit 1 Base	2	7.0	0.25
# Forsburn	Nair	Hit 1 Tip	3	8.0	0.2
# Forsburn	Nair	Hit 2	2	7.0	0.25
# Forsburn	Nair	Hit 3	4	6.0	0.5
# Forsburn	Fair	Fair	6	6.0	0.5
# Forsburn	Bair	Sweet	11	5.2	1.025
# Forsburn	Bair	Sour	4	5.2	0.4
# Forsburn	Dair	Sweet	10	4.8	0.7
# Forsburn	Dair	Spike	11	6.0	0.5
# Forsburn	Uair	Early Tip	7	4.25	0.85
# Forsburn	Uair	Early Base	6	4.25	0.75
# Forsburn	Uair	Late Tip	5	4.0	0.55
# Forsburn	Uair	Late Base	5	4.0	0.5
# Forsburn	Uspecial	Uspecial	8	8.0	0.5
# Forsburn	Dspecial	Sweet	10	7.0	1.0
# Forsburn	Dspecial	Sour	7	5.5	0.85
# Forsburn	Pummel	Pummel	8	4.0	0.0	True
# Forsburn	PummelSpecial	Pummel	2	4.0	0.0	True
# Forsburn	Fthrow	Fthrow	6	9.0	0.35	True	True
# Forsburn	Bthrow	Bthrow	6	9.0	0.5	True	True
# Forsburn	Uthrow	Throw	3	9.0	0.5	True	True
# Forsburn	Dthrow	Dthrow	6	8.0	0.23	True	True
# Forsburn	LedgeAttack	Lattack	6	8.0	0.3
# Forsburn	LedgeSpecial	Travel	4	10.0	0.0	True
# Forsburn	LedgeSpecial	Landing	5	10.0	0.3
# Forsburn	LedgeSpecial	Explosion	8	10.0	0.3
# Forsburn	GetupAttack	Gattack	6	9.0	0.25
# Forsburn	GetupSpecial	Gspecial	8	9.0	0.25
# Forsburn	Dspecial_Clone	Normal	8	6.0	0.1
# Forsburn	Dspecial_Clone	Empowered Sweet	12	6.0	0.75
# Forsburn	Dspecial_Clone	Empowered Sour	10	5.5	0.6
# Forsburn	Fspecial_Clone	Final	6	6.0	0.65
# Kragg	Jab	Jab 1 KB	3	4.0	0.0	True
# Kragg	Jab	Jab 2 KB	3	4.0	0.0	True
# Kragg	Jab	Jab 3 KB	6	6.5	0.625
# Kragg	Ftilt	Ftilt KB	7	6.25	0.7
# Kragg	Utilt	Hit 1	3	8.0	0.0	True	True
# Kragg	Utilt	Hit 2	7	7.0	0.7		True
# Kragg	Dtilt	Dtilt KB	7	4.0	0.45
# Kragg	Dattack	Dattack KB	8	6.0	0.45
# Kragg	Fstrong	Fstrong KB	18	9.0	1.15
# Kragg	Ustrong	Early	16	8.0	1.1
# Kragg	Ustrong	Late	6	6.0	0.8
# Kragg	Dstrong	Sweetspot	11	7.0	1.2
# Kragg	Dstrong	Sourspot	10	6.0	1.15
# Kragg	Nair	Hit 1	4	7.0	0.15	True
# Kragg	Nair	Hit 2	4	7.0	0.15	True
# Kragg	Nair	Hit 3	4	7.0	0.3
# Kragg	Nair	Hit 4	8	7.0	0.4
# Kragg	Fair	Sweet	11	5.0	0.9
# Kragg	Fair	Sour	7	3.5	0.8
# Kragg	Bair	Early	9	6.0	0.55
# Kragg	Bair	Late	7	5.0	0.4
# Kragg	Dair	Dair KB	11	6.0	0.5
# Kragg	Uair	Sweetspot	11	5.5	0.925
# Kragg	Uair	Sourspot	8	6.0	0.75
# Kragg	Fspecial	Rolling KB	4	6.5	0.1
# Kragg	Pummel	Pummel	8	4.0	0.0	True
# Kragg	PummelSpecial	Pummel	8	4.0	0.0	True
# Kragg	Fthrow	Fthrow	7	7.0	0.525	True
# Kragg	Bthrow	Throw	7	9.0	0.4	True	True
# Kragg	Uthrow	Uthrow	5	10.0	0.35	True	True
# Kragg	Dthrow	Dthrow	3	6.5	0.25	True
# Kragg	LedgeAttack	Lattack	6	8.0	0.3
# Kragg	LedgeSpecial	Lspecial	10	10.0	0.0
# Kragg	GetupAttack	Gattack	6	9.0	0.25
# Kragg	GetupSpecial	Hit 1	3	8.0	0.0	True
# Kragg	GetupSpecial	Hit 2	5	10.0	0.4
# Kragg	DspecialAir	Spike	14	5.0	0.6
# Kragg	Rock_Dthrow	Throw	4	7.0	0.2	True	True
# Kragg	Rock_Fthrow	Throw	4	10.0	0.35	True	True
# Kragg	Rock_Nthrow	Throw	4	9.0	0.25	True	True
# Kragg	Rock_Uthrow	Throw	4	10.0	0.55	True	True
# Kragg	Taunt1	Taunt Spike	4	5.0	0.3	True
# Kragg	Taunt2	Taunt Spike	4	5.0	0.3	True
# Kragg	Earthquake	Earthquake KB	4	8.0	0.0	True	True
# Kragg	EarthSpike1	First Spike	2	7.0	0.0	True
# Kragg	EarthSpike2	Second Spike	4	7.0	0.0	True
# Kragg	EarthSpike3	Final Spike	10	11.0	0.2
# Kragg	Pillar	Aerial	7	9.0	0.0	True
# Kragg	Pillar	Grounded	7	9.0	0.0	True
# Kragg	Rock	Nthrow KB	8	7.0	0.4
# Kragg	Rock	Fthrow KB	8	8.0	0.4
# Kragg	Rock	Uthrow KB	8	7.0	0.4
# Kragg	Rock	Dthrow KB	8	6.0	0.2		True
# Kragg	RockShard	Shard KB	2	5.0	0.3
# Loxodont	Jab	Jab 1 Sweet	5	6.0	0.0	True
# Loxodont	Jab	Jab 1 Sour	4	6.0	0.0	True
# Loxodont	Jab	Jab 2 Sweet	6	7.0	0.4
# Loxodont	Jab	Jab 2 Sour	4	6.0	0.35
# Loxodont	Ftilt	Sweet	10	8.5	0.7
# Loxodont	Ftilt	Sour	6	7.0	0.55
# Loxodont	Ftilt	Pull	4	6.0	0.0	True
# Loxodont	Utilt	Early	9	7.0	0.75
# Loxodont	Utilt	Mid	8	6.5	0.65
# Loxodont	Utilt	Late	6	6.0	0.55
# Loxodont	Dtilt	Sweet	12	5.5	0.5
# Loxodont	Dtilt	Sour	12	9.0	0.4
# Loxodont	Dattack	Early	8	6.0	0.5
# Loxodont	Dattack	Late	5	5.0	0.3
# Loxodont	Dattack	Lava	5	3.0	0.4
# Loxodont	Fstrong	Sweet Early	14	6.5	0.89
# Loxodont	Fstrong	Sour Early	11	6.5	0.8
# Loxodont	Fstrong	Sweet Late	16	7.0	1.185
# Loxodont	Fstrong	Sour Late	13	7.0	0.95
# Loxodont	Ustrong	Sweet	14	6.5	1.135
# Loxodont	Ustrong	Sour	12	6.5	1.05
# Loxodont	Ustrong	Late	7	5.0	0.75
# Loxodont	Dstrong	Sweet Early	16	7.0	1.04
# Loxodont	Dstrong	Sour Early	13	5.0	0.9
# Loxodont	Dstrong	Sweet Late	12	7.0	0.75
# Loxodont	Dstrong	Sour Late	10	4.0	0.65
# Loxodont	Nair	Hit 1	4	4.0	0.2
# Loxodont	Nair	Hit 2	4	7.0	0.45
# Loxodont	Nair	Hit 3	5	7.0	0.55
# Loxodont	Fair	Sweet	10	4.0	0.72
# Loxodont	Fair	Sour	7	5.5	0.4
# Loxodont	Bair	Sweet	12	4.5	1.13
# Loxodont	Bair	Sour	8	3.0	0.9
# Loxodont	Dair	Stomp	13	6.0	0.6
# Loxodont	Uair	Sweet Early	9	4.2	0.92
# Loxodont	Uair	Sweet Late	8	3.0	0.85
# Loxodont	Uair	Sour	6	4.0	0.5
# Loxodont	Nspecial	Launch	9	8.0	0.85
# Loxodont	Fspecial	Throw	12	8.0	0.25	True	True
# Loxodont	Uspecial	Rising Front	4	12.0	0.0	True
# Loxodont	Uspecial	Rising Back	4	12.0	0.0	True
# Loxodont	Uspecial	Falling	5	10.0	0.1	True
# Loxodont	Uspecial	Landing	6	7.0	0.5		True
# Loxodont	Dspecial	Flub	2	4.0	0.0	True
# Loxodont	Dspecial	Level 1	9	9.0	0.3	True
# Loxodont	Dspecial	Level 2	12	11.0	0.3	True
# Loxodont	Dspecial	Level 3	15	13.0	0.3	True
# Loxodont	Pummel	Pummel	8	4.0	0.0	True
# Loxodont	PummelSpecial	Pummel	3	4.0	0.0	True
# Loxodont	Fthrow	Sweet	8	9.0	0.7	True	True
# Loxodont	Fthrow	Sour	6	9.0	0.65	True	True
# Loxodont	Fthrow	Throw	2	8.2	0.0	True	True
# Loxodont	Bthrow	Throw	7	8.0	0.55	True	True
# Loxodont	Uthrow	Uthrow	5	10.0	0.4	True	True
# Loxodont	Dthrow	Lava Hit	4	8.0	0.375	True	True
# Loxodont	Dthrow	Throw	5	8.0	0.0	True	True
# Loxodont	LedgeAttack	Lattack	6	8.0	0.3
# Loxodont	LedgeSpecial	Lspecial	9	10.0	0.3
# Loxodont	GetupAttack	Gattack	6	9.0	0.25
# Loxodont	GetupSpecial	Explosion	12	10.0	0.4
# Loxodont	GetupSpecial	Flub	3	6.0	0.35
# Loxodont	Eruption	Level 1	9	9.0	0.25	True
# Loxodont	Eruption	Level 2	12	11.5	0.2	True
# Loxodont	Eruption	Level 3	15	14.0	0.15	True
# Loxodont	LavaBurstDstrong1	Multihit	1	4.0	0.0	True
# Loxodont	LavaBurstDstrong1	Final	4	7.0	1.04
# Loxodont	LavaBurstDstrong2	Multihit	1	4.0	0.0	True
# Loxodont	LavaBurstDstrong2	Final	4	7.0	1.04
# Loxodont	LavaBurstFstrong	Multihit	1	4.0	0.0	True
# Loxodont	LavaBurstFstrong	Final Sweet	4	7.0	1.185
# Loxodont	LavaBurstFstrong	Final Sour	4	6.5	0.89
# Loxodont	LavaBurstUstrong	Multihit	1	4.0	0.0	True
# Loxodont	LavaBurstUstrong	Final Sweet	4	6.5	1.135
# Loxodont	LavaBurstUstrong	Final Sour	4	6.5	1.05
# Loxodont	LavaBurstUstrong	Final Backward	4	5.0	0.75
# Loxodont	LavaPool	Activation	1	0.0	0.0
# Loxodont	MoltenBoulder	Boulder KB	4	8.0	0.35
# Maypul	Jab	Jab KB	3	4.0	0.0	True
# Maypul	Ftilt	Ftilt	8	6.0	0.5
# Maypul	Utilt	Utilt	8	6.0	0.85
# Maypul	Dtilt	Dtilt	7	5.5	0.6
# Maypul	Dattack	Hit 1	3	8.0	0.0	True	True
# Maypul	Dattack	Hit 2	5	9.0	0.4
# Maypul	Fstrong	Sweet	11	7.0	1.05
# Maypul	Fstrong	Sour	10	6.0	0.9
# Maypul	Ustrong	Sweet	11	7.5	1.1
# Maypul	Ustrong	Sour	10	6.5	1.0
# Maypul	Dstrong	Dstrong Front	10	7.0	1.0
# Maypul	Dstrong	Dstrong Back	10	7.0	1.0
# Maypul	Nair	Early	8	7.0	0.5
# Maypul	Nair	Late	4	5.0	0.3
# Maypul	Fair	Fair	8	4.5	0.45
# Maypul	Bair	Hit 1	4	5.0	0.25	True
# Maypul	Bair	Hit 2	5	6.0	0.5
# Maypul	Uair	Multihit	2	3.3	0.0	True
# Maypul	Uair	Multihit Tether	2	5.0	0.0	True
# Maypul	Uair	Final	5	5.5	0.9
# Maypul	Fspecial	Fspecial	4	6.0	0.3
# Maypul	Uspecial	Hit 1	4	8.0	0.5
# Maypul	Uspecial	Hit 2 Early	8	6.0	1.08
# Maypul	Uspecial	Hit 2 Late	6	6.0	0.93
# Maypul	Pummel	Pummel	8	4.0	0.0	True
# Maypul	PummelSpecial	SPummel	8	4.0	0.0	True
# Maypul	Fthrow	Fthrow	4	9.5	0.35	True
# Maypul	Bthrow	Bthrow	4	9.5	0.35	True
# Maypul	Uthrow	Uthrow	3	10.0	0.45	True	True
# Maypul	Dthrow	Swing KB	6	8.0	0.6
# Maypul	Dthrow	Throw	6	8.0	0.15	True	True
# Maypul	LedgeAttack	Lattack	3	8.0	0.3
# Maypul	GetupAttack	Gattack	6	9.0	0.25
# Maypul	GetupSpecial	Dive	4	6.0	0.0	True
# Maypul	GetupSpecial	Landing	6	9.0	0.3
# Maypul	DspecialAir	Dspecial	4	8.0	0.3
# Maypul	Lily	Bite	4	6.0	0.3
# Maypul	Lily	Wrap	4	6.0	0.3
# Maypul	Poppy	Pop KB	3	6.0	0.3
# Maypul	Root	Dair	5	5.0	0.4
# Maypul	Seed	Seed KB	1	0.0	0.0	True
# Maypul	Terry	Terry KB	3	7.0	0.3
# Orcane	Jab	Jab 1	3	4.0	0.0	True
# Orcane	Jab	Jab 2	3	4.0	0.0	True
# Orcane	Jab	Jab Final	6	7.0	0.35
# Orcane	Ftilt	Ftilt	10	5.0	0.86
# Orcane	Utilt	Sweet	6	6.0	0.45
# Orcane	Utilt	Sour	4	5.0	0.35
# Orcane	Dtilt	Sweet	9	7.5	0.4
# Orcane	Dtilt	Sour	7	5.5	0.25
# Orcane	Dattack	Early	7	6.5	0.35
# Orcane	Dattack	Late	5	5.0	0.3
# Orcane	Fstrong	Normal	9	7.0	0.95
# Orcane	Fstrong	Puddle	14	7.0	0.95
# Orcane	Ustrong	Normal Sweet	10	9.0	1.15
# Orcane	Ustrong	Normal Sour	8	8.0	1.0
# Orcane	Ustrong	Puddle Sweet	15	9.0	1.15
# Orcane	Ustrong	Puddle Sour	12	8.0	1.0
# Orcane	Dstrong	Normal	9	7.5	1.05
# Orcane	Dstrong	Puddle	11	7.5	1.05
# Orcane	Nair	Sweetspot	7	4.0	0.825
# Orcane	Nair	Sourspot	5	4.0	0.4
# Orcane	Fair	Strong	9	6.0	0.95
# Orcane	Fair	Weak	7	6.0	0.5
# Orcane	Bair	Sour	6	6.0	0.25
# Orcane	Bair	Sweet	8	7.5	0.95
# Orcane	Dair	Dair	3	3.0	0.25
# Orcane	Uair	Water Sweet	9	7.5	0.99
# Orcane	Uair	Water Sour	7	6.8	0.8
# Orcane	Uair	Belly	6	5.0	0.4
# Orcane	Fspecial	Normal	8	7.0	0.4
# Orcane	Fspecial	Puddle	14	8.0	0.85
# Orcane	Uspecial	Sweetspot	12	9.0	1.2
# Orcane	Uspecial	Sourspot	10	8.0	1.0
# Orcane	Pummel	Pummel	8	4.0	0.0	True
# Orcane	PummelSpecial	Pummel	6	4.0	0.0	True
# Orcane	Fthrow	Normal	7	9.0	0.45	True	True
# Orcane	Fthrow	Empowered	10	9.0	0.7	True	True
# Orcane	Bthrow	Bthrow	6	9.0	0.65	True	True
# Orcane	Uthrow	Throw	2	6.0	0.0	True
# Orcane	Dthrow	Dthrow	5	8.0	0.2	True	True
# Orcane	LedgeAttack	Lattack	4	8.0	0.3
# Orcane	LedgeAttack	Lattack 2	4	8.0	0.3
# Orcane	LedgeSpecial	Multihit	3	4.0	0.0	True
# Orcane	LedgeSpecial	Final	3	8.0	0.4
# Orcane	GetupAttack	Gattack	6	9.0	0.25
# Orcane	GetupSpecial	Gspecial	8	9.0	0.25
# Orcane	Bubble	Forward KB	1	4.0	0.0	True
# Orcane	Bubble	Upward KB	1	4.0	0.0	True
# Orcane	Droplet	Nspecial	6	4.0	0.25
# Orcane	Droplet	Dspecial	6	4.0	0.2
# Ranno	Jab	Jab 1	2	4.0	0.0	True
# Ranno	Jab	Jab 2	2	4.0	0.0	True
# Ranno	Jab	Jab Final	2	6.0	0.0	True
# Ranno	Jab	Rapid Jab	1	3.0	0.0	True
# Ranno	Ftilt	Hit 1	3	3.5	0.0
# Ranno	Ftilt	Hit 2 Front	6	6.0	0.5
# Ranno	Ftilt	Hit 2 Back	5	4.0	0.4
# Ranno	Utilt	Utilt Early	9	7.0	0.65
# Ranno	Utilt	Utilt Late	7	6.0	0.5
# Ranno	Dtilt	Dtilt Sour	6	6.0	0.4
# Ranno	Dtilt	Dtilt Sweet	7	6.0	0.4
# Ranno	Dattack	Sweet	7	6.0	0.7
# Ranno	Dattack	Sour	5	4.5	0.65
# Ranno	Fstrong	Sweetspot	12	6.5	1.0
# Ranno	Fstrong	Sourspot	9	6.0	0.8
# Ranno	Ustrong	Sweetspot	13	8.0	1.07
# Ranno	Ustrong	Early Sour	10	7.5	0.85
# Ranno	Ustrong	Late Sour	8	7.0	0.8
# Ranno	Dstrong	Sweetspot	11	6.0	0.8
# Ranno	Dstrong	Sourspot	9	6.0	0.75
# Ranno	Nair	Sweetspot	7	3.3	0.92
# Ranno	Nair	Sweetspot Back	6	4.0	0.6
# Ranno	Nair	Sourspot	5	3.0	0.6
# Ranno	Fair	Fair Spike	10	4.0	0.6
# Ranno	Fair	Fair Sweet	9	4.0	0.85
# Ranno	Fair	Fair Sour	7	5.0	0.5
# Ranno	Bair	Early Sweetspot	8	5.0	0.8
# Ranno	Bair	Early Sourspot	6	4.0	0.7
# Ranno	Bair	Early Reverse	5	3.0	0.5
# Ranno	Bair	Late Sweetspot	6	3.5	0.7
# Ranno	Bair	Late Sourspot	4	3.0	0.6
# Ranno	Bair	Late Reverse	3	2.0	0.45
# Ranno	Dair	Hit 1	3	5.0	0.0
# Ranno	Dair	Hit 2	3	5.0	0.0
# Ranno	Dair	Final Hit	6	6.0	0.45
# Ranno	Uair	Hit 1 Low	3	6.5	0.0
# Ranno	Uair	Hit 1 Mid	3	5.5	0.0
# Ranno	Uair	Hit 1 High	3	4.5	0.0
# Ranno	Uair	Hit 2 Sweet	5	5.0	0.9
# Ranno	Uair	Hit 2 Sour	4	5.0	0.75
# Ranno	Fspecial	Tick Damage	2	0.0	0.0
# Ranno	Uspecial	Rising Hit	4	8.0	0.2
# Ranno	Uspecial	Rising Hit Late	4	6.0	0.1
# Ranno	Uspecial	Divekick	5	8.0	0.65
# Ranno	Uspecial	Spin Multihit	1	4.0	0.0	True
# Ranno	Uspecial	Spin Final	1	10.0	0.35
# Ranno	Uspecial	Divekick Landing	5	8.0	0.65
# Ranno	Pummel	Pummel	8	4.0	0.0	True
# Ranno	PummelSpecial	Pummel	1	4.0	0.0	True
# Ranno	Fthrow	Throw	5	9.0	0.4	True
# Ranno	Bthrow	Bthrow	4	8.0	0.6	True	True
# Ranno	Uthrow	Uthrow	4	12.0	0.25	True	True
# Ranno	Dthrow	Dthrow	3	8.0	0.3	True	True
# Ranno	LedgeAttack	Lattack	6	8.0	0.3
# Ranno	LedgeSpecial	Front	5	13.0	0.0	True
# Ranno	LedgeSpecial	Back	5	12.0	0.0	True
# Ranno	GetupAttack	Gattack	6	9.0	0.25
# Ranno	PoisonDart	Dart KB	1	4.0	0.1	True
# Ranno	PoisonDartUspecial	Dart KB	1	4.0	0.1	True
# Ranno	PoisonPalm	Palm KB	5	7.0	1.0
# Wrastor	Jab	Jab 1	3	4.0	0.0	True
# Wrastor	Jab	Jab 2	3	4.0	0.0	True
# Wrastor	Jab	Jab 3	6	6.0	0.75
# Wrastor	Ftilt	Multihit	3	4.0	0.0	True
# Wrastor	Ftilt	Final Hit	3	6.5	0.7
# Wrastor	Utilt	Top	10	7.0	1.0
# Wrastor	Utilt	Spike	10	8.0	0.45
# Wrastor	Utilt	Sour	8	7.0	0.8
# Wrastor	Dtilt	Sweet	7	5.5	0.65
# Wrastor	Dtilt	Sour	5	5.0	0.4
# Wrastor	Dattack	Early	7	7.0	0.5
# Wrastor	Dattack	Late	5	5.0	0.5
# Wrastor	Fstrong	Sweetspot	14	7.0	1.0
# Wrastor	Fstrong	Sourspot	10	6.0	0.8
# Wrastor	Ustrong	Sweetspot	13	7.0	1.05
# Wrastor	Ustrong	Sourspot	9	6.0	1.0
# Wrastor	Dstrong	Dstrong	11	6.0	0.6
# Wrastor	Nair	Hit 1	3	5.0	0.2
# Wrastor	Nair	Hit 2 Early	5	4.5	0.875
# Wrastor	Nair	Hit 2 Late	4	3.0	0.6
# Wrastor	Fair	Base	7	5.0	0.65
# Wrastor	Fair	Tipper	5	4.0	0.6
# Wrastor	Bair	Sweetspot	6	4.0	0.9
# Wrastor	Bair	Sourspot	5	4.0	0.65
# Wrastor	Dair	Feet	7	7.0	0.5
# Wrastor	Dair	Wing Spike	6	3.0	0.6
# Wrastor	Uair	Early	7	5.5	0.75
# Wrastor	Uair	Late	5	4.0	0.5
# Wrastor	Nspecial	Multihit	1	6.0	0.0	True
# Wrastor	Nspecial	Multihit Bottom	1	8.0	0.0	True
# Wrastor	Nspecial	Final Hit	3	5.0	0.65
# Wrastor	Uspecial	Sweetspot	14	6.5	1.2
# Wrastor	Uspecial	Sour Early	7	6.0	0.35
# Wrastor	Uspecial	Sour Late	6	5.0	0.35
# Wrastor	Dspecial	Hit Object	14	7.0	0.0
# Wrastor	Dspecial	Throw	9	10.0	0.4	True	True
# Wrastor	Pummel	Pummel	8	4.0	0.0	True
# Wrastor	PummelSpecial	Spummel	3	4.0	0.0	True
# Wrastor	Fthrow	Fthrow	6	7.0	0.5	True
# Wrastor	Bthrow	Bthrow	5	7.0	0.45	True
# Wrastor	Bthrow	Spike	5	5.0	0.15	True
# Wrastor	Uthrow	Uthrow	4	12.0	0.25	True	True
# Wrastor	Dthrow	Throw	3	8.0	0.0	True	True
# Wrastor	LedgeAttack	Lattack	4	8.0	0.3
# Wrastor	LedgeSpecial	Landing KB	12	10.0	0.65
# Wrastor	LedgeSpecial	Dive KB	4	8.0	0.0	True
# Wrastor	GetupAttack	Gattack	6	9.0	0.25
# Wrastor	GetupSpecial	Multihit	1	3.0	0.0	True
# Wrastor	GetupSpecial	Final Hit	3	9.0	0.25
# Wrastor	DspecialAir	Landing	8	8.0	0.3
# Wrastor	DspecialAir	Hit Object	14	5.0	0.0
# Wrastor	DspecialAir	Throw	9	10.0	0.4	True	True
# Wrastor	SlipstreamSplitter	Proj KB	3	3.5	0.0
# Wrastor	SlipstreamTornado	Proj KB	3	3.5	0.0
# Zetterburn	Jab	Jab 1	3	4.0	0.0	True
# Zetterburn	Jab	Jab 2	3	4.0	0.0	True
# Zetterburn	Jab	Jab Final	6	6.0	0.5
# Zetterburn	Ftilt	Linking Hit	4	4.5	0.825
# Zetterburn	Ftilt	Final Hit	4	4.5	0.825
# Zetterburn	Utilt	Sweet	7	7.0	0.65
# Zetterburn	Utilt	Sour	6	5.5	0.75
# Zetterburn	Dtilt	Sweetspot	7	6.0	0.5
# Zetterburn	Dtilt	Sourspot	5	5.0	0.3
# Zetterburn	Dattack	Sweetspot	6	7.0	0.3
# Zetterburn	Dattack	Sourspot	4	6.0	0.3
# Zetterburn	Fstrong	Linking Hit	2	6.0	0.0	True
# Zetterburn	Fstrong	Final Hit	8	8.0	0.9		True
# Zetterburn	Fstrong	Consume	6	7.5	1.1		True
# Zetterburn	Ustrong	Ustrong KB	12	8.0	1.0
# Zetterburn	Ustrong	Consume	6	8.0	1.15
# Zetterburn	Dstrong	Hit 1 Cross	4	3.0	0.0	True	True
# Zetterburn	Dstrong	Hit 1 Far	4	10.0	0.0	True	True
# Zetterburn	Dstrong	Hit 1 Mid	4	8.0	0.0	True	True
# Zetterburn	Dstrong	Hit 1 Close	4	8.0	0.0	True	True
# Zetterburn	Dstrong	Hit 2	6	8.0	0.8		True
# Zetterburn	Dstrong	Consume	6	8.0	1.0		True
# Zetterburn	Nair	Multihit	2	6.0	0.0	True
# Zetterburn	Nair	Multihit Ground	2	6.0	0.0	True
# Zetterburn	Nair	Final Hit	3	6.0	0.6
# Zetterburn	Fair	Sweetspot	11	5.0	0.88
# Zetterburn	Fair	Sourspot	6	5.0	0.3
# Zetterburn	Bair	Sourspot	2	5.0	0.4
# Zetterburn	Bair	Tipper	3	5.0	0.4
# Zetterburn	Dair	Sweetspot	12	6.0	0.6
# Zetterburn	Dair	Sourspot	10	5.0	0.55
# Zetterburn	Uair	Sweetspot	9	8.0	0.8
# Zetterburn	Uair	Sourspot	5	6.0	0.6
# Zetterburn	Uair	Super Sour	4	4.0	0.65
# Zetterburn	Nspecial	Uncharged	2	7.0	0.15
# Zetterburn	Nspecial	Charged	10	9.0	0.3
# Zetterburn	Fspecial	Mane KB	3	6.0	0.1	True
# Zetterburn	Uspecial	Multihit	1	3.0	0.0	True
# Zetterburn	Uspecial	Final Hit	5	7.0	0.6
# Zetterburn	Dspecial	Slam KB	7	10.0	0.55
# Zetterburn	Pummel	Pummel	8	4.0	0.0	True
# Zetterburn	PummelSpecial	Pummel	6	4.0	0.0	True
# Zetterburn	Fthrow	Normal	6	10.0	0.6	True	True
# Zetterburn	Fthrow	Empowered	7	10.5	0.7	True	True
# Zetterburn	Bthrow	Throw	5	9.0	0.45	True	True
# Zetterburn	Uthrow	Uthrow	4	10.0	0.35	True	True
# Zetterburn	Dthrow	Dthrow	4	8.0	0.25	True	True
# Zetterburn	LedgeAttack	Lattack	6	8.0	0.3
# Zetterburn	LedgeSpecial	Lspecial	5	10.0	0.3
# Zetterburn	GetupAttack	Gattack	6	9.0	0.25
# Zetterburn	GetupSpecial	Gspecial	7	9.0	0.25
# Zetterburn	DspecialAir	Dive KB	2	10.0	0.15	True
# Zetterburn	DspecialAir	Dive KB Ground	2	4.0	0.0	True
# Zetterburn	Fireball	Fireball KB	2	6.0	0.1
